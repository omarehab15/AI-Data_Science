# %%
# !pip install bs4
# !pip install lmxl
# !pip install html5
# !pip install requests
# Out:
# Requirement already satisfied: bs4 in c:\users\omar\miniconda3\lib\site-packages (0.0.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\omar\miniconda3\lib\site-packages (from bs4) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\omar\miniconda3\lib\site-packages (from beautifulsoup4->bs4) (2.6)
# ERROR: Could not find a version that satisfies the requirement lmxl (from versions: none)
# ERROR: No matching distribution found for lmxl
# Requirement already satisfied: html5 in c:\users\omar\miniconda3\lib\site-packages (0.0.9)
# Requirement already satisfied: setuptools>=18.5 in c:\users\omar\miniconda3\lib\site-packages (from html5) (75.1.0)
# Requirement already satisfied: six in c:\users\omar\miniconda3\lib\site-packages (from html5) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\omar\miniconda3\lib\site-packages (from html5) (0.5.1)
# Requirement already satisfied: requests in c:\users\omar\miniconda3\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\omar\miniconda3\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\omar\miniconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\omar\miniconda3\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\omar\miniconda3\lib\site-packages (from requests) (2024.8.30)

# %%
import requests
site = requests.request('GET', 'https://wuzzuf.net/jobs/egypt')
print(site)
print(site.text)
# Out:
# <Response [200]>
# <!DOCTYPE html>
# <html lang="en" translate="no">
# <head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0, shrink-to-fit=no">
#     <meta http-equiv="expires" content="Thu Dec 08 2022 18:30:44 GMT+0200" />
#
#     <meta http-equiv="Pragma" content="no-cache">
#     <meta http-equiv="cache-control" content="no-cache, no-store, must-revalidate">
#     <meta name="googlebot" content="notranslate">
#     <title data-react-helmet="true">8,453 Job Opportunities in Egypt - Apply Today!</title>
#
# <meta data-react-helmet="true" name="description" content="Explore 8,453 job vacancies in Egypt. Find your next opportunity with a top recruitment company. Apply now and jumpstart your future!"/><meta data-react-helmet="true" property="og:title" content="8,453 Job Opportunities in Egypt - Apply Today!"/><meta data-react-helmet="true" property="og:description" content="Explore 8,453 job vacancies in Egypt. Find your next opportunity with a top recruitment company. Apply now and jumpstart your future!"/><meta data-react-helmet="true" property="og:url" content="https://wuzzuf.net/jobs/egypt"/><meta data-react-helmet="true" property="og:type" content="Website"/><meta data-react-helmet="true" property="og:site_name" content="Wuzzuf"/><meta data-react-helmet="true" property="og:image" content="https://static.wuzzuf-data.net/js-og-img-e1c37427f7e3d177bb60efd4d4e88571.jpg"/><meta data-react-helmet="true" property="og:image:secure_url" content="https://static.wuzzuf-data.net/js-og-img-e1c37427f7e3d177bb60efd4d4e88571.jpg"/><meta data-react-helmet="true" property="og:country_name" content="Egypt"/><meta data-react-helmet="true" property="twitter:title" content="8,453 Job Opportunities in Egypt - Apply Today!"/><meta data-react-helmet="true" property="twitter:description" content="Explore 8,453 job vacancies in Egypt. Find your next opportunity with a top recruitment company. Apply now and jumpstart your future!"/><meta data-react-helmet="true" property="twitter:image" content="https://static.wuzzuf-data.net/js-og-img-e1c37427f7e3d177bb60efd4d4e88571.jpg"/><meta data-react-helmet="true" name="keywords" content="jobs in Egypt, job in Egypt, careers egypt, jobs in Cairo, jobs in alexandria, employment in egypt, Egypt jobs, jobs vacancies, job vacancies in egypt, job search egypt, job vacancies egypt, job recruitment in egypt, job opportunities in egypt, jobs cairo, job vacancy egypt , وظائف مصر"/>
#
# <link data-react-helmet="true" rel="canonical" href="https://wuzzuf.net/jobs/egypt"/><link data-react-helmet="true" rel="alternate" href="https://wuzzuf.net/jobs/egypt" hrefLang="en-EG"/><link data-react-helmet="true" rel="alternate" href="https://wuzzuf.net/saudi/jobs" hrefLang="en-SA"/>
#
#     <link rel="manifest" href="/manifest.json">
#
#     <link rel="icon" href="https://wuzzuf.net/favicon.ico">
#
#     <link data-chunk="index" rel="preload" as="script" href="https://static.wuzzuf-data.net/vendor-1740310555633.c0359e6c4dac3e799e4a.js">
# <link data-chunk="index" rel="preload" as="script" href="https://static.wuzzuf-data.net/index-1740310555633.9c41399101f237ae6e98.js">
# <link data-chunk="guest-jobseeker-landing-page-egypt" rel="preload" as="script" href="https://static.wuzzuf-data.net/7791-1740310555633.686a2b14b15273dfb473.js">
# <link data-chunk="guest-jobseeker-landing-page-egypt" rel="preload" as="script" href="https://static.wuzzuf-data.net/7603-1740310555633.3dd87b0daa5eaf99ac5e.js">
# <link data-chunk="guest-jobseeker-landing-page-egypt" rel="preload" as="script" href="https://static.wuzzuf-data.net/4571-1740310555633.ed7c0975286ae8763afa.js">
# <link data-chunk="guest-jobseeker-landing-page-egypt" rel="preload" as="script" href="https://static.wuzzuf-data.net/6334-1740310555633.b136bb51d8bbf27e9545.js">
# <link data-chunk="guest-jobseeker-landing-page-egypt" rel="preload" as="script" href="https://static.wuzzuf-data.net/5798-1740310555633.be580ee938f216ec6ca7.js">
# <link data-chunk="guest-jobseeker-landing-page-egypt" rel="preload" as="script" href="https://static.wuzzuf-data.net/2195-1740310555633.c1624b79ae60153308a3.js">
# <link data-chunk="guest-jobseeker-landing-page-egypt" rel="preload" as="script" href="https://static.wuzzuf-data.net/7583-1740310555633.99b30fb54aecc12fbcae.js">
# <link data-chunk="guest-jobseeker-landing-page-egypt" rel="preload" as="script" href="https://static.wuzzuf-data.net/7863-1740310555633.5bb0bf26d64a72649bb8.js">
# <link data-chunk="guest-jobseeker-landing-page-egypt" rel="preload" as="script" href="https://static.wuzzuf-data.net/guest-footer-1740310555633.7194506b1fe664702440.js">
# <link data-chunk="guest-jobseeker-landing-page-egypt" rel="preload" as="script" href="https://static.wuzzuf-data.net/4772-1740310555633.f978e49fd86fa2049ba0.js">
# <link data-chunk="guest-jobseeker-landing-page-egypt" rel="preload" as="script" href="https://static.wuzzuf-data.net/3411-1740310555633.0f5822c9acabd78ee904.js">
# <link data-chunk="guest-jobseeker-landing-page-egypt" rel="preload" as="script" href="https://static.wuzzuf-data.net/7740-1740310555633.e2d742639873c3334ac3.js">
# <link data-chunk="guest-jobseeker-landing-page-egypt" rel="preload" as="script" href="https://static.wuzzuf-data.net/5872-1740310555633.44ea7c77c34ddc25d542.js">
# <link data-chunk="guest-jobseeker-landing-page-egypt" rel="preload" as="script" href="https://static.wuzzuf-data.net/4012-1740310555633.bb31f340e7c08f1b442e.js">
# <link data-chunk="guest-jobseeker-landing-page-egypt" rel="preload" as="script" href="https://static.wuzzuf-data.net/guest-jobseeker-landing-page-egypt-1740310555633.0a38009bf49485c39ba3.js">
#
#     <link rel="preload" href="https://fonts.googleapis.com/css?family=Open+Sans:300,300i,400,400i,600,600i,700,700i&display=swap" as="style" onload="this.onload=null;this.rel='stylesheet'">
#     <noscript><link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Open+Sans:300,300i,400,400i,600,600i,700,700i&display=swap"></noscript>
#
#     <style>
#         html, body { padding: 0; margin: 0; font-family: 'Open Sans', sans-serif; }
#         input, textarea, select, button { font-family: 'Open Sans', sans-serif; }
#         * { box-sizing: border-box; }
#     </style>
#     <link rel="stylesheet" href="https://static.wuzzuf-data.net/css/global.css" media="print" onload="this.onload=null;this.rel='stylesheet';this.media='all'">
#     <link rel="stylesheet" type="text/css" href="https://static.wuzzuf-data.net/css/lib.css" media="print" onload="this.onload=null;this.rel='stylesheet';this.media='all'">
# </head>
# <body>
#     <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-T4Z552" height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
#
#     <div id="app"><div><style data-emotion="css zgjfei">.css-zgjfei{position:relative;overflow-x:clip;}</style><div class="css-zgjfei"><style data-emotion="css 79elbk">.css-79elbk{position:relative;}</style><div class="css-79elbk"><style data-emotion="css 1sea5n0">.css-1sea5n0{z-index:9998;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;top:0;left:0;right:0;height:62px;width:100%;padding-top:30px;position:absolute;}</style><header class="css-1sea5n0"><style data-emotion="css 11gef4w">.css-11gef4w{width:100%;max-width:90vw;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:justify;-webkit-justify-content:space-between;justify-content:space-between;padding:0 10px;}</style><div class="css-11gef4w"><style data-emotion="css xarv33">.css-xarv33{margin-right:24px;}.css-xarv33 path{fill:#ffffff;}</style><style data-emotion="css 1drtgx9">.css-1drtgx9{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:start;-webkit-box-align:start;-ms-flex-align:start;align-items:start;position:relative;cursor:pointer;width:125px;margin-right:24px;}.css-1drtgx9 path{fill:#ffffff;}</style><a aria-label="navigate to wuzzuf home page" class="css-1drtgx9 e19qcx5a0" href="/jobs/egypt"><svg viewBox="0 0 125 20" xmlns="http://www.w3.org/2000/svg" aria-labelledby="wuzzuf-logo"><path fill="#0055D9" d="M23.724.001h4.906L22.583 20H18.17L14.315 7.96 10.489 20H6.046L0 .001h4.936L8.793 12.32 12.587 0h3.61l3.671 12.319L23.724 0zm9.147 17.552c-1.604-1.63-2.406-3.823-2.406-6.577V.001h4.689v11.036c0 1.54.432 2.714 1.296 3.524.864.81 2.046 1.215 3.548 1.215 1.48 0 2.648-.405 3.502-1.215.853-.81 1.28-1.985 1.28-3.524V0h4.689v10.975c0 2.754-.792 4.947-2.376 6.577C45.51 19.184 43.145 20 39.998 20s-5.523-.815-7.127-2.446zm18.416-.694L62.456 3.95H51.565V.001h16.69v3.17L57.15 16.052h11.106V20H51.287v-3.14zm18.803 0L81.258 3.95h-10.89V.001h16.69v3.17l-11.106 12.88h11.106v3.948H70.09v-3.14zm21.226.694c-1.605-1.63-2.407-3.823-2.407-6.577V.001h4.69v11.036c0 1.54.432 2.714 1.295 3.524.864.81 2.047 1.215 3.548 1.215 1.481 0 2.648-.405 3.502-1.215.853-.81 1.28-1.985 1.28-3.524V0h4.69v10.975c0 2.754-.793 4.947-2.376 6.577-1.584 1.631-3.949 2.446-7.096 2.446-3.147 0-5.522-.815-7.126-2.446zm23.279-5.733V20h-4.69V0H125l-1.08 3.982h-9.325V8.18h7.959l-.99 3.64h-6.97z"></path></svg></a><div class="css-0"><style data-emotion="css 1bgvccj">.css-1bgvccj{font-size:15px;font-weight:600;-webkit-text-decoration:none;text-decoration:none;margin-right:12px;padding:12px;cursor:pointer;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:#ffffff;}</style><a href="#" class="css-1bgvccj">Browse Jobs<style data-emotion="css 1q4vxyr">.css-1q4vxyr{margin-left:8px;}</style><style data-emotion="css ks9dan">.css-ks9dan{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;line-height:1em;width:16px;height:16px;margin-left:8px;}</style><i size="16" class="css-ks9dan efou2fk0"><svg width="16" height="16" preserveAspectRatio="none" viewBox="0 0 24 24"><path fill="#ffffff" d="M17.355 7.5L12 13.063 6.645 7.5 5 9.213l7 7.287 7-7.287z"></path></svg></i></a></div><style data-emotion="css yujhzj">.css-yujhzj{-webkit-flex:2;-ms-flex:2;flex:2;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}</style><div class="css-yujhzj"><style data-emotion="css logigj">.css-logigj{width:110px;margin-right:12px;}</style><div class="css-logig ...
#
#     <script>
#         (function(){
#             var Wuzzuf = window.Wuzzuf = window.Wuzzuf || {};
#             Wuzzuf.country = {"country":"Egypt","countryId":"","subFolder":"","subFolderName":"egypt","defaultCountryQueryParams":"","capital":"Cairo","jobseekerHomePage":"\u002Fjobs\u002Fegypt","empHomePage":"\u002Frecruitment\u002Fegypt","hrefLang":"en-EG","viewerCountryIso":"eg"};
#             Wuzzuf.headers = {"host":"wuzzuf.net","x-request-id":"ba98152f411d4636cb220ab65c385709","x-real-ip":"41.239.156.63","x-forwarded-for":"41.239.156.63","x-forwarded-host":"wuzzuf.net","x-forwarded-port":"80","x-forwarded-proto":"http","x-forwarded-scheme":"http","x-scheme":"http","x-original-forwarded-for":"41.239.156.63, 64.252.88.209","x-amzn-trace-id":"Root=1-67bb385c-57b1f26c3590406520e2b4ea","user-agent":"Amazon CloudFront","x-amz-cf-id":"AKyMovoBUdrG0kKt0xRECnpUrimCOzRp_np2B2QQqHKl_QM3yHQJGQ==","if-none-match":"W\u002F\"69a39-MJVQ0uNnFSSKl\u002FBOCok50\u002Fy4Oys\"","via":"2.0 9e1ca2a082cf3304834fbd01d8598ce4.cloudfront.net (CloudFront)","accept-encoding":"gzip","sec-ch-ua":"\"Not(A:Brand\";v=\"99\", \"Google Chrome\";v=\"133\", \"Chromium\";v=\"133\"","sec-ch-ua-mobile":"?1","sec-ch-ua-platform":"\"Android\"","upgrade-insecure-requests":"1","sec-fetch-site":"cross-site","sec-fetch-mode":"navigate","sec-fetch-user":"?1","sec-fetch-dest":"document","priority":"u=0, i"};
#             Wuzzuf.isServerRendered = true;
#             Wuzzuf.initialStoreState = {"badges":{"landingPage":{"timestamp":null,"providers":null,"loading":false}},"browsingPage":{"sets":{},"metaTemplateType":{}},"communityPages":{"internship":{"jobs":{},"filters":{"isLoading":true,"isError":false,"error":null,"sets":{}},"hotJobs":null},"alexandria":{"jobs":{},"filters":{"isLoading":true,"isError":false,"error":null,"sets":{}},"hotJobs":null},"android":{"jobs":{},"filters":{"isLoading":true,"isError":false,"error":null,"sets":{}},"hotJobs":null},"pharmaceutical":{"jobs":{},"filters":{"isLoading":true,"isError":false,"error":null,"sets":{}},"hotJobs":null},"workFromHome":{"jobs":{},"filters":{"isLoading":true,"isError":false,"error":null,"sets":{}},"hotJobs":null},"startups":{"jobs":{},"filters":{"isLoading":true,"isError":false,"error":null,"sets":{}},"hotJobs":null}},"entities":{"companyPlanBenefit":{"isLoading":false,"collection":{},"error":null,"timestamp":null},"applicationStatistics":{"isLoading":false,"collection":{},"error":null,"timestamp":null},"badge":{"isLoading":false,"collection":{},"error":null,"timestamp":null},"badgeGradeDetails":{"isLoading":false,"collection":{},"error":null,"timestamp":null},"company":{"collection":{"403":{"id":"403","type":"company","attributes":{"uniqueId":"c694d328-9373-11ea-add1-062a4819e772","name":"B.TECH","legalName":null,"logo":"B-Tech-Egypt-403-1645525431.png","slug":"B-Tech-Egypt-403","description":"B.TECH is an Egyptian shareholding company; founded in 1997, and is the largest retailer specialized in trading and distributing home appliances and electronics in the Arab Republic of Egypt. We take pride in bringing the latest technologies and financial solutions to our customers everyday. ","specialties":[],"hiringFor":null,"website":"https:\u002F\u002Fbtech.com\u002F","facebookPage":null,"twitterAccount":null,"linkedinProfile":null,"blog":null,"onlinePresence":{"facebook":null,"twitter":null,"linkedin":null,"blog":null,"website":"https:\u002F\u002Fbtech.com\u002F","instagram":null,"youtube":null,"vimeo":null,"behance":null},"establishedYear":"","uniqueName":"B.TECH -w- 403","taxId":null,"street":"-","isPersonal":false,"buildingNumber":"-","area":"-","publicStatus":{"id":1,"name":"Verified"},"statusUpdatedAt":null,"createdAt":"05\u002F22\u002F2012 21:17:28","perks":[]},"links":{"self":"https:\u002F\u002Fwuzzuf.net\u002Fapi\u002Fcompany\u002F403","defaultLogoUrl":"https:\u002F\u002Fimages.wuzzuf-data.net\u002Ffiles\u002Fcompany_logo\u002FB-Tech-Egypt-403-1645525431.png","orgLogoUrl":"https:\u002F\u002Fimages.wuzzuf-data.net\u002Ffiles\u002Fcompany_logo\u002FB-Tech-Egypt-403-1645525431-org.png","smLogoUrl":"https:\u002F\u002Fimages.wuzzuf-data.net\u002Ffiles\u002Fcompany_logo\u002FB-Tech-Egypt-403-1645525431-sm.png","xsLogoUrl":"https:\u002F\u002Fimages.wuzzuf-data.net\u002Ffiles\u002Fcompany_logo\u002FB-Tech-Egypt-403-1645525431-xs.png","ogLogoUrl":"https:\u002F\u002Fimages.wuzzuf-data.net\u002Ffiles\u002Fcompany_logo\u002FB-Tech-Egypt-403-1645525431-og.png","defaultCoverUrl":"https:\u002F\u002Fimages.wuzzuf-data.net\u002Ffiles\u002Fcompany_covers\u002F559727436642e877d43e80.png","coverUrl":"https:\u002F\u002Fimages.wuzzuf-data.net\u002Ffiles\u002Fcompany_covers\u002Fthumbs\u002F559727436642e877d43e80.png","profile":"jobs\u002Fcareers\u002FB-Tech-Egypt-403"},"relationships":{"workIndustries":{"data":[{"id":"158770","type":"companyWorkIndustry"}]},"featuredLogos":{"data":[{"id":"968","type":"companyFeaturedLogo"}]},"country":{"data":{"id":"56","type":"country"}},"city":{"data":{"id":"1545","type":"city"}},"size":{"data":{"id":"6","type":"companySize"}},"type":{"data":null}}},"766":{"id":"766","type":"company","attributes":{"uniqueId":"c69716af-9373-11ea-add1-062a4819e772","name":"Premium Card","legalName":null,"logo":"17463337946728b1e9bb788.png","slug":"Premium-Card-Egypt-766","description":"Premium Card for Financial Services established an interest-free credit card, with a payment plan over 10  months","specialties":[],"hiringFo ...
#             Wuzzuf.serverRenderedURL = "/jobs/egypt";
#             Wuzzuf.userType = "guest";
#         }());
#     </script>
#     <script>
#         window.addEventListener('beforeinstallprompt', function(){
#             e.preventDefault();
#         });
#     </script>
#
#     <script id="__LOADABLE_REQUIRED_CHUNKS__" type="application/json">[7791,7603,4571,6334,5798,2195,7583,7863,9825,4772,3411,7740,5872,4012,1452]</script><script id="__LOADABLE_REQUIRED_CHUNKS___ext" type="application/json">{"namedChunks":["guest-jobseeker-landing-page-egypt"]}</script>
# <script defer data-chunk="index" src="https://static.wuzzuf-data.net/vendor-1740310555633.c0359e6c4dac3e799e4a.js"></script>
# <script defer data-chunk="index" src="https://static.wuzzuf-data.net/index-1740310555633.9c41399101f237ae6e98.js"></script>
# <script defer data-chunk="guest-jobseeker-landing-page-egypt" src="https://static.wuzzuf-data.net/7791-1740310555633.686a2b14b15273dfb473.js"></script>
# <script defer data-chunk="guest-jobseeker-landing-page-egypt" src="https://static.wuzzuf-data.net/7603-1740310555633.3dd87b0daa5eaf99ac5e.js"></script>
# <script defer data-chunk="guest-jobseeker-landing-page-egypt" src="https://static.wuzzuf-data.net/4571-1740310555633.ed7c0975286ae8763afa.js"></script>
# <script defer data-chunk="guest-jobseeker-landing-page-egypt" src="https://static.wuzzuf-data.net/6334-1740310555633.b136bb51d8bbf27e9545.js"></script>
# <script defer data-chunk="guest-jobseeker-landing-page-egypt" src="https://static.wuzzuf-data.net/5798-1740310555633.be580ee938f216ec6ca7.js"></script>
# <script defer data-chunk="guest-jobseeker-landing-page-egypt" src="https://static.wuzzuf-data.net/2195-1740310555633.c1624b79ae60153308a3.js"></script>
# <script defer data-chunk="guest-jobseeker-landing-page-egypt" src="https://static.wuzzuf-data.net/7583-1740310555633.99b30fb54aecc12fbcae.js"></script>
# <script defer data-chunk="guest-jobseeker-landing-page-egypt" src="https://static.wuzzuf-data.net/7863-1740310555633.5bb0bf26d64a72649bb8.js"></script>
# <script defer data-chunk="guest-jobseeker-landing-page-egypt" src="https://static.wuzzuf-data.net/guest-footer-1740310555633.7194506b1fe664702440.js"></script>
# <script defer data-chunk="guest-jobseeker-landing-page-egypt" src="https://static.wuzzuf-data.net/4772-1740310555633.f978e49fd86fa2049ba0.js"></script>
# <script defer data-chunk="guest-jobseeker-landing-page-egypt" src="https://static.wuzzuf-data.net/3411-1740310555633.0f5822c9acabd78ee904.js"></script>
# <script defer data-chunk="guest-jobseeker-landing-page-egypt" src="https://static.wuzzuf-data.net/7740-1740310555633.e2d742639873c3334ac3.js"></script>
# <script defer data-chunk="guest-jobseeker-landing-page-egypt" src="https://static.wuzzuf-data.net/5872-1740310555633.44ea7c77c34ddc25d542.js"></script>
# <script defer data-chunk="guest-jobseeker-landing-page-egypt" src="https://static.wuzzuf-data.net/4012-1740310555633.bb31f340e7c08f1b442e.js"></script>
# <script defer data-chunk="guest-jobseeker-landing-page-egypt" src="https://static.wuzzuf-data.net/guest-jobseeker-landing-page-egypt-1740310555633.0a38009bf49485c39ba3.js"></script>
#
#         <script defer src='https://static.cloudflareinsights.com/beacon.min.js' data-cf-beacon='{"token": "c0ca6af573dc4cd5973fdbdea3c92282"}'></script>
#
#
# </body>
# </html>

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(site.text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" translate="no">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0, shrink-to-fit=no" name="viewport"/>
#   <meta content="Thu Dec 08 2022 18:30:44 GMT+0200" http-equiv="expires">
#    <meta content="no-cache" http-equiv="Pragma"/>
#    <meta content="no-cache, no-store, must-revalidate" http-equiv="cache-control"/>
#    <meta content="notranslate" name="googlebot"/>
#    <title data-react-helmet="true">
#     8,453 Job Opportunities in Egypt - Apply Today!
#    </title>
#    <meta content="Explore 8,453 job vacancies in Egypt. Find your next opportunity with a top recruitment company. Apply now and jumpstart your future!" data-react-helmet="true" name="description">
#     <meta content="8,453 Job Opportunities in Egypt - Apply Today!" data-react-helmet="true" property="og:title">
#      <meta content="Explore 8,453 job vacancies in Egypt. Find your next opportunity with a top recruitment company. Apply now and jumpstart your future!" data-react-helmet="true" property="og:description">
#       <meta content="https://wuzzuf.net/jobs/egypt" data-react-helmet="true" property="og:url">
#        <meta content="Website" data-react-helmet="true" property="og:type">
#         <meta content="Wuzzuf" data-react-helmet="true" property="og:site_name"/>
#         <meta content="https://static.wuzzuf-data.net/js-og-img-e1c37427f7e3d177bb60efd4d4e88571.jpg" data-react-helmet="true" property="og:image"/>
#         <meta content="https://static.wuzzuf-data.net/js-og-img-e1c37427f7e3d177bb60efd4d4e88571.jpg" data-react-helmet="true" property="og:image:secure_url"/>
#         <meta content="Egypt" data-react-helmet="true" property="og:country_name"/>
#         <meta content="8,453 Job Opportunities in Egypt - Apply Today!" data-react-helmet="true" property="twitter:title"/>
#         <meta content="Explore 8,453 job vacancies in Egypt. Find your next opportunity with a top recruitment company. Apply now and jumpstart your future!" data-react-helmet="true" property="twitter:description"/>
#         <meta content="https://static.wuzzuf-data.net/js-og-img-e1c37427f7e3d177bb60efd4d4e88571.jpg" data-react-helmet="true" property="twitter:image"/>
#         <meta content="jobs in Egypt, job in Egypt, careers egypt, jobs in Cairo, jobs in alexandria, employment in egypt, Egypt jobs, jobs vacancies, job vacancies in egypt, job search egypt, job vacancies egypt, job recruitment in egypt, job opportunities in egypt, jobs cairo, job vacancy egypt , وظائف مصر" data-react-helmet="true" name="keywords"/>
#         <link data-react-helmet="true" href="https://wuzzuf.net/jobs/egypt" rel="canonical"/>
#         <link data-react-helmet="true" href="https://wuzzuf.net/jobs/egypt" hreflang="en-EG" rel="alternate"/>
#         <link data-react-helmet="true" href="https://wuzzuf.net/saudi/jobs" hreflang="en-SA" rel="alternate"/>
#         <link href="/manifest.json" rel="manifest"/>
#         <link href="https://wuzzuf.net/favicon.ico" rel="icon"/>
#         <link as="script" data-chunk="index" href="https://static.wuzzuf-data.net/vendor-1740310555633.c0359e6c4dac3e799e4a.js" rel="preload"/>
#         <link as="script" data-chunk="index" href="https://static.wuzzuf-data.net/index-1740310555633.9c41399101f237ae6e98.js" rel="preload"/>
#         <link as="script" data-chunk="guest-jobseeker-landing-page-egypt" href="https://static.wuzzuf-data.net/7791-1740310555633.686a2b14b15273dfb473.js" rel="preload"/>
#         <link as="script" data-chunk="guest-jobseeker-landing-page-egypt" href="https://static.wuzzuf-data.net/7603-1740310555633.3dd87b0daa5eaf99ac5e.js" rel="preload"/>
#         <link as="script" data-chunk="guest-jobseeker-landing-page-egypt" href="https://static.wuzzuf-data.net/4571-1740310555633.ed7c0975286ae8763afa.js" rel="preload"/>
#         <link as="script" data-chunk="guest-jobseeker-landing-page-egypt" href="https://static.wuzzuf-data.net/6334-1740310555633.b136bb51d8bbf27e9545.js" rel="preload"/>
#         <link as="script" data-chunk="guest-jobseeker-landing-page-egypt" href="https://static.wuzzuf-data.net/5798-1740310555633.be580ee938f216ec6ca7.js" rel="preload"/>
#         <link as="script" data-chunk="guest-jobseeker-landing-page-egypt" href="https://static.wuzzuf-data.net/2195-1740310555633.c1624b79ae60153308a3.js" rel="preload"/>
#         <link as="script" data-chunk="guest-jobseeker-landing-page-egypt" href="https://static.wuzzuf-data.net/7583-1740310555633.99b30fb54aecc12fbcae.js" rel="preload"/>
#         <link as="script" data-chunk="guest-jobseeker-landing-page-egypt" href="https://static.wuzzuf-data.net/7863-1740310555633.5bb0bf26d64a72649bb8.js" rel="preload"/>
#         <link as="script" data-chunk="guest-jobseeker-landing-page-egypt" href="https://static.wuzzuf-data.net/guest-footer-1740310555633.7194506b1fe664702440.js" rel="preload"/>
#         <link as="script" data-chunk="guest-jobseeker-landing-page-egypt" href="https://static.wuzzuf-data.net/4772-1740310555633.f978e49fd86fa2049ba0.js" rel="preload"/>
#         <link as="script" data-chunk="guest-jobseeker-landing-page-egypt" href="https://static.wuzzuf-data.net/3411-1740310555633.0f5822c9acabd78ee904.js" rel="preload"/>
#         <link as="script" data-chunk="guest-jobseeker-landing-page-egypt" href="https://static.wuzzuf-data.net/7740-1740310555633.e2d742639873c3334ac3.js" rel="preload"/>
#         <link as="script" data-chunk="guest-jobseeker-landing-page-egypt" href="https://static.wuzzuf-data.net/5872-1740310555633.44ea7c77c34ddc25d542.js" rel="preload"/>
#         <link as="script" data-chunk="guest-jobseeker-landing-page-egypt" href="https://static.wuzzuf-data.net/4012-1740310555633.bb31f340e7c08f1b442e.js" rel="preload"/>
#         <link as="script" data-chunk="guest-jobseeker-landing-page-egypt" href="https://static.wuzzuf-data.net/guest-jobseeker-landing-page-egypt-1740310555633.0a38009bf49485c39ba3.js" rel="preload"/>
#         <link as="style" href="https://fonts.googleapis.com/css?family=Open+Sans:300,300i,400,400i,600,600i,700,700i&amp;display=swap" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
#         <noscript>
#          <link href="https://fonts.googleapis.com/css?family=Open+Sans:300,300i,400,400i,600,600i,700,700i&amp;display=swap" rel="stylesheet"/>
#         </noscript>
#         <style>
#          html, body { padding: 0; margin: 0; font-family: 'Open Sans', sans-serif; }
#         input, textarea, select, button { font-family: 'Open Sans', sans-serif; }
#         * { box-sizing: border-box; }
#         </style>
#         <link href="https://static.wuzzuf-data.net/css/global.css" media="print" onload="this.onload=null;this.rel='stylesheet';this.media='all'" rel="stylesheet"/>
#         <link href="https://static.wuzzuf-data.net/css/lib.css" media="print" onload="this.onload=null;this.rel='stylesheet';this.media='all'" rel="stylesheet" type="text/css"/>
#        </meta>
#       </meta>
#      </meta>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body>
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-T4Z552" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <div id="app">
#    <div>
#     <style data-emotion="css zgjfei">
#      .css-zgjfei{position:relative;overflow-x:clip;}
#     </style>
#     <div class="css-zgjfei">
#      <style data-emotion="css 79elbk">
#       .css-79elbk{position:relative;}
#      </style>
#      <div class="css-79elbk">
#       <style data-emotion="css 1sea5n0">
#        .css-1sea5n0{z-index:9998;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;top:0;left:0;right:0;height:62px;width:100%;padding-top:30px;position:absolute;}
#       </style>
#       <header class="css-1sea5n0">
#        <style data-emotion="css 11gef4w">
#         .css-11gef4w{width:100%;max-width:90vw;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:justify;-webkit-justify-content:space-between;justify-content:space-between;padding:0 10px;}
#        </style>
#        <div class="css-11gef4w">
#         <style data-emotion="css xarv33">
#          .css-xarv33{margin-right:24px;}.css-xarv33 path{fill:#ffffff;}
#         </style>
#         <style data-emotion="css 1drtgx9">
#          .css-1drtgx9{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:start;-webkit-box-align:start;-ms-flex-align:start;align-items:start;position:relative;cursor:pointer;width:125px;margin-right:24px;}.css-1drtgx9 path{fill:#ffffff;}
#         </style>
#         <a aria-label="navigate to wuzzuf home page" class="css-1drtgx9 e19qcx5a0" href="/jobs/egypt">
#          <svg aria-labelledby="wuzzuf-logo" viewbox="0 0 125 20" xmlns="http://www.w3.org/2000/svg">
#           <path d="M23.724.001h4.906L22.583 20H18.17L14.315 7.96 10.489 20H6.046L0 .001h4.936L8.793 12.32 12.587 0h3.61l3.671 12.319L23.724 0zm9.147 17.552c-1.604-1.63-2.406-3.823-2.406-6.577V.001h4.689v11.036c0 1.54.432 2.714 1.296 3.524.864.81 2.046 1.215 3.548 1.215 1.48 0 2.648-.405 3.502-1.215.853-.81 1.28-1.985 1.28-3.524V0h4.689v10.975c0 2.754-.792 4.947-2.376 6.577C45.51 19.184 43.145 20 39.998 20s-5.523-.815-7.127-2.446zm18.416-.694L62.456 3.95H51.565V.001h16.69v3.17L57.15 16.052h11.106V20H51.287v-3.14zm18.803 0L81.258 3.95h-10.89V.001h16.69v3.17l-11.106 12.88h11.106v3.948H70.09v-3.14zm21.226.694c-1.605-1.63-2.407-3.823-2.407-6.577V.001h4.69v11.036c0 1.54.432 2.714 1.295 3.524.864.81 2.047 1.215 3.548 1.215 1.481 0 2.648-.405 3.502-1.215.853-.81 1.28-1.985 1.28-3.524V0h4.69v10.975c0 2.754-.793 4.947-2.376 6.577-1.584 1.631-3.949 2.446-7.096 2.446-3.147 0-5.522-.815-7.126-2.446zm23.279-5.733V20h-4.69V0H125l-1.08 3.982h-9.325V8.18h7.959l-.99 3.64h-6.97z" fill="#0055D9">
#           </path>
#          </svg>
#         </a>
#         <div class="css-0">
#          <style data-emotion="css 1bgvccj">
#           .css-1bgvccj{font-size:15px;font-weight:600;-webkit-text-decoration:none;text-decoration:none;margin-right:12px;padding:12px;cursor:pointer;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:#ffffff;}
#          </style>
#          <a class="css-1bgvccj" href="#">
#           Browse Jobs
#           <style data-emotion="css 1q4vxyr">
#            .css-1q4vxyr{margin-left:8px;}
#           </style>
#           <style data-emotion="css ks9dan">
#            .css-ks9dan{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;line-height:1em;width:16px;height:16px;margin-left:8px;}
#           </style>
#           <i class="css-ks9dan efou2fk0" size="16">
#            <svg height="16" preserveaspectratio="none" viewbox="0 0 24 24" width="16">
#             <path d="M17.355 7.5L12 13.063 6.645 7.5 5 9.213l7 7.287 7-7.287z" fill="#ffffff">
#             </path>
#            </svg>
#           </i>
#          </a>
#         </div>
#         <style data-emotion="css yujhzj">
#          .css-yujhzj{-webkit-flex:2;-ms-flex:2;flex:2;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
#         </style>
#         <div class="css-yujhzj">
#          <style data-emotion="css logigj">
#           .css-logigj{width:110px;margin-right:12px;}
#          </style>
#          <div class="css-logigj">
#           <style data-emotion="css znqlam">
#            .css-znqlam{-webkit-text-decoration:none;text-decoration:none;color:#ffffff;font-size:15px;font-weight:600;}
#           </style>
#           <a as="[object Object]" class="css-znqlam" href="/recruitment/egypt">
#            For Employers
#           </a>
#          </div>
#         </div>
#         <style data-emotion="css s5xdrg">
#          .css-s5xdrg{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
#         </style>
#         <div class="css-s5xdrg">
#          <style data-emotion="css cwf6fk">
#           .css-cwf6fk{height:40px;border-radius:4px;color:#ffffff;font-size:15px;font-weight:600;margin-right:4px;padding-inline:12px;}.css-cwf6fk:hover{background-color:rgba(0, 0, 0, 0.4);}
#          </style>
#          <style data-emotion="css pybf1h">
#           .css-pybf1h{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:15px;padding:0 12px;border:1px solid transparent;border-radius:2px;-webkit-text-decoration:none;text-decoration:none;text-align:center;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;cursor:pointer;min-width:80px;-webkit-transition:color .2s ease,background-color .2s ease,border-color .2s ease;transition:color .2s ease,background-color .2s ease,border-color .2s ease;min-height:32px;line-height:22px;color:#4D6182;background-color:transparent;border-color:transparent;height:40px;border-radius:4px;color:#ffffff;font-size:15px;font-weight:600;margin-right:4px;padding-inline:12px;}.css-pybf1h:focus{outline:none;}.css-pybf1h:disabled{opacity:0.25;cursor:not-allowed;}.css-pybf1h:hover{background-color:#EBEDF0;}.css-pybf1h:active{background-color:#D9DDE4;}.css-pybf1h:focus{border-color:#80B2FF;}.css-pybf1h:disabled{opacity:0.5;}.css-pybf1h:disabled:hover{background-color:transparent;}.css-pybf1h:hover{background-color:rgba(0, 0, 0, 0.4);}
#          </style>
#          <a aria-label="navigate to create a new job post " btntype="subtle" class="css-pybf1h eswc9qo0" href="/employer/register">
#           <style data-emotion="css ydg8ex">
#            .css-ydg8ex{margin-top:7px;}
#           </style>
#           <style data-emotion="css 1fdpd19">
#            .css-1fdpd19{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;line-height:1em;width:25px;height:25px;margin-top:7px;}
#           </style>
#           <i class="css-1fdpd19 efou2fk0" size="25">
#            <svg height="25" preserveaspectratio="none" viewbox="0 0 24 24" width="25">
#             <path d="M10.5 4.875V3.375H7.5V4.875H10.5ZM3 7.125V13.875C3 14.2875 3.3375 14.625 3.75 14.625H14.25C14.6625 14.625 15 14.2875 15 13.875V7.125C15 6.7125 14.6625 6.375 14.25 6.375H3.75C3.3375 6.375 3 6.7125 3 7.125ZM15 4.875C15.8325 4.875 16.5 5.5425 16.5 6.375V14.625C16.5 15.4575 15.8325 16.125 15 16.125H3C2.1675 16.125 1.5 15.4575 1.5 14.625L1.5075 6.375C1.5075 5.5425 2.1675 4.875 3 4.875H6V3.375C6 2.5425 6.6675 1.875 7.5 1.875H10.5C11.3325 1.875 12 2.5425 12 3.375V4.875H15Z" fill="#ffffff">
#             </path>
#            </svg>
#           </i>
#           Post Job
#          </a>
#          <style data-emotion="css no09ly">
#           .css-no09ly{height:24px;width:1px;background-color:#D9DDE4;margin-right:16px;}
#          </style>
#          <span class="css-no09ly">
#          </span>
#          <style data-emotion="css xgdhpw">
#           .css-xgdhpw{height:40px;color:#ffffff;border:1px solid #ffffff;border-radius:4px;padding-block:8px;padding-inline:10px;font-size:15px;font-weight:600;}.css-xgdhpw:hover{background-color:rgba(0, 0, 0, 0.4);}
#          </style>
#          <style data-emotion="css nc2d4i">
#           .css-nc2d4i{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:15px;padding:0 12px;border:1px solid transparent;border-radius:2px;-webkit-text-decoration:none;text-decoration:none;text-align:center;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;cursor:pointer;min-width:80px;-webkit-transition:color .2s ease,background-color .2s ease,border-color .2s ease;transition:color .2s ease,background-color .2s ease,border-color .2s ease;min-height:32px;line-height:22px;color:#4D6182;background-color:transparent;border-color:transparent;height:40px;color:#ffffff;border:1px solid #ffffff;border-radius:4px;padding-block:8px;padding-inline:10px;font-size:15px;font-weight:600;}.css-nc2d4i:focus{outline:none;}.css-nc2d4i:disabled{opacity:0.25;cursor:not-allowed;}.css-nc2d4i:hover{background-color:#EBEDF0;}.css-nc2d4i:active{background-color:#D9DDE4;}.css-nc2d4i:focus{border-color:#80B2FF;}.css-nc2d4i:disabled{opacity:0.5;}.css-nc2d4i:disabled:hover{background-color:transparent;}.css-nc2d4i:hover{background-color:rgba(0, 0, 0, 0.4);}
#          </style>
#          <a aria-label="navigate to login page" btntype="subtle" class="css-nc2d4i eswc9qo0" href="/login">
#           Log in
#          </a>
#          <style data-emotion="css d37o1i">
#           .css-d37o1i{height:40px;margin-right:6px;border-radius:4px;margin-left:12px;padding-block:8px;padding-inline:18px;font-size:15px;font-weight:600;}
#          </style>
#          <style data-emotion="css 1ith43a">
#           .css-1ith43a{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:15px;padding:0 12px;border:1px solid transparent;border-radius:2px;-webkit-text-decoration:none;text-decoration:none;text-align:center;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;cursor:pointer;min-width:80px;-webkit-transition:color .2s ease,background-color .2s ease,border-color .2s ease;transition:color .2s ease,background-color .2s ease,border-color .2s ease;min-height:32px;line-height:22px;color:#ffffff;background-color:#0055D9;height:40px;margin-right:6px;border-radius:4px;margin-left:12px;padding-block:8px;padding-inline:18px;font-size:15px;font-weight:600;}.css-1ith43a:focus{outline:none;}.css-1ith43a:disabled{opacity:0.25;cursor:not-allowed;}.css-1ith43a:hover{background-color:#0046B2;}.css-1ith43a:active{background-color:#00327F;}.css-1ith43a:focus{border-color:#80B2FF;}.css-1ith43a:disabled:hover{background-color:#0055D9;}
#          </style>
#          <a aria-label="navigate to sign up page" btntype="primary" class="css-1ith43a eswc9qo0" href="/register">
#           Get Started
#          </a>
#          <style data-emotion="css 1r5gb7q">
#           .css-1r5gb7q{display:inline-block;}
#          </style>
#          <div class="css-1r5gb7q">
#           <div class="css-0">
#            <style data-emotion="css 11l7j55">
#             .css-11l7j55{line-height:1em;padding:8px;vertical-align:middle;border:none;border-radius:4px;}.css-11l7j55:hover{background-color:rgba(0, 0, 0, 0.4);}.css-11l7j55:hover path{fill:#ffffff;}.css-11l7j55:focus{border:none;}
#            </style>
#            <style data-emotion="css 1icsxbk">
#             .css-1icsxbk{min-height:auto;min-width:auto;padding:8px;vertical-align:middle;line-height:1em;padding:8px;vertical-align:middle;border:none;border-radius:4px;}.css-1icsxbk:hover{background-color:rgba(0, 0, 0, 0.4);}.css-1icsxbk:hover path{fill:#ffffff;}.css-1icsxbk:focus{border:none;}
#            </style>
#            <style data-emotion="css 1yuss1i">
#             .css-1yuss1i{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:15px;padding:0 12px;border:1px solid transparent;border-radius:2px;-webkit-text-decoration:none;text-decoration:none;text-align:center;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;cursor:pointer;min-width:80px;-webkit-transition:color .2s ease,background-color .2s ease,border-color .2s ease;transition:color .2s ease,background-color .2s ease,border-color .2s ease;min-height:32px;line-height:22px;color:#4D6182;background-color:transparent;border-color:transparent;min-height:auto;min-width:auto;padding:8px;vertical-align:middle;line-height:1em;padding:8px;vertical-align:middle;border:none;border-radius:4px;}.css-1yuss1i:focus{outline:none;}.css-1yuss1i:disabled{opacity:0.25;cursor:not-allowed;}.css-1yuss1i:hover{background-color:#EBEDF0;}.css-1yuss1i:active{background-color:#D9DDE4;}.css-1yuss1i:focus{border-color:#80B2FF;}.css-1yuss1i:disabled{opacity:0.5;}.css-1yuss1i:disabled:hover{background-color:transparent;}.css-1yuss1i:hover{background-color:rgba(0, 0, 0, 0.4);}.css-1yuss1i:hover path{fill:#ffffff;}.css-1yuss1i:focus{border:none;}
#            </style>
#            <button aria-label="toggle navigation menu" class="css-1yuss1i ezfki8j0" type="button">
#             <style data-emotion="css yb1q05">
#              .css-yb1q05{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;line-height:1em;width:22px;height:22px;}
#             </style>
#             <i class="css-yb1q05 efou2fk0" size="22">
#              <svg height="22" preserveaspectratio="none" viewbox="0 0 24 24" width="22">
#               <path d="M3 18h18v-2H3v2zm0-5h18v-2H3v2zm0-7v2h18V6H3z" fill="#ffffff">
#               </path>
#              </svg>
#             </i>
#            </button>
#           </div>
#          </div>
#         </div>
#        </div>
#       </header>
#      </div>
#      <style data-emotion="css 12ohe60">
#       .css-12ohe60{margin-bottom:-80px;background-color:#ffffff;position:relative;overflow:hidden;}
#      </style>
#      <main class="css-12ohe60">
#       <style data-emotion="css 236qt2">
#        .css-236qt2{position:absolute;height:100vh;top:0;bottom:0;width:100vw;background:linear-gradient(180deg, rgba(0,0,0,0.35) 0%, rgba(0,0,0,0.35) 90%, rgba(0,0,0,0.0) 100%);z-index:1;}
#       </style>
#       <div class="css-236qt2">
#       </div>
#       <style data-emotion="css dnei0q">
#        .css-dnei0q{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;position:absolute;height:100vh;top:0px;width:100vw;}
#       </style>
#       <div class="css-dnei0q">
#        <style data-emotion="css ch3brz">
#         .css-ch3brz{max-width:1170px;margin:0 auto;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;-webkit-box-flex-flow:column;-webkit-flex-flow:column;-ms-flex-flow:column;flex-flow:column;padding:24px;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;z-index:999;}@media screen and (max-width: 991px){.css-ch3brz{margin:0;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}}
#        </style>
#        <div class="css-ch3brz">
#         <style data-emotion="css 1dd9gec">
#          .css-1dd9gec{color:#ffffff;font-size:38px;font-weight:600;letter-spacing:-0.75px;line-height:42px;margin:0 0 16px;text-shadow:1px 1px 40px #16171f;}@media screen and (min-width: 992px){.css-1dd9gec{margin:0 0 8px;font-size:42px;line-height:66px;letter-spacing:-1.05px;}}
#         </style>
#         <h1 class="css-1dd9gec">
#          Find the Best Jobs in Egypt
#         </h1>
#         <style data-emotion="css mpnzl4">
#          .css-mpnzl4{color:#ffffff;font-size:20px;letter-spacing:-0.5px;font-weight:normal;margin:0 0 24px;line-height:29px;text-shadow:1px 1px 40px #16171f;}@media screen and (max-width: 991px){.css-mpnzl4{margin:0 0 32px;font-size:16px;letter-spacing:-0.4px;font-weight:normal;line-height:24px;text-align:center;}}
#         </style>
#         <h2 class="css-mpnzl4">
#          Searching for vacancies &amp; career opportunities? WUZZUF helps you in your job search in Egypt
#         </h2>
#         <style data-emotion="css 8u5tv3">
#          .css-8u5tv3{background:#ffffff;border-radius:4px;box-shadow:0px 0px 1px 0px rgba(0, 0, 0, 0.1),0px 1px 2px 0px rgba(0, 0, 0, 0.1);height:56px;width:100%;max-width:920px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:12px;position:relative;}@media screen and (min-width: 992px){.css-8u5tv3{min-width:920px;height:74px;}}
#         </style>
#         <form action="/search/jobs" autocomplete="off" class="css-8u5tv3" method="GET" role="search">
#          <style data-emotion="css 1lmmxxi">
#           .css-1lmmxxi{border:none;padding-left:44px;background-color:#ffffff;position:relative;}.css-1lmmxxi:focus{box-shadow:none;background-color:#ffffff;}.css-1lmmxxi::-webkit-input-placeholder{font-size:20px;font-weight:200;}.css-1lmmxxi::-moz-placeholder{font-size:20px;font-weight:200;}.css-1lmmxxi:-ms-input-placeholder{font-size:20px;font-weight:200;}.css-1lmmxxi::placeholder{font-size:20px;font-weight:200;}@media screen and (max-width: 991px){.css-1lmmxxi::-webkit-input-placeholder{font-size:14px;}.css-1lmmxxi::-moz-placeholder{font-size:14px;}.css-1lmmxxi:-ms-input-placeholder{font-size:14px;}.css-1lmmxxi::placeholder{font-size:14px;}}
#          </style>
#          <style data-emotion="css 3nd8v7">
#           .css-3nd8v7{position:relative;-webkit-flex:1;-ms-flex:1;flex:1;}
#          </style>
#          <div class="css-3nd8v7">
#           <style data-emotion="css 1ode3cm">
#            .css-1ode3cm{left:0;}
#           </style>
#           <style data-emotion="css 1igbm66">
#            .css-1igbm66{position:absolute;top:0;bottom:0;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;padding:0 8px;left:0;}
#           </style>
#           <span class="css-1igbm66 e1n2h7jb0">
#            <style data-emotion="css 16w6w5b">
#             .css-16w6w5b{z-index:999;}
#            </style>
#            <style data-emotion="css xrmp6">
#             .css-xrmp6{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;line-height:1em;width:24px;height:24px;z-index:999;}
#            </style>
#            <i class="css-xrmp6 efou2fk0" size="24">
#             <svg height="24" preserveaspectratio="none" viewbox="0 0 24 24" width="24">
#              <path d="M15.462 10.615a4.852 4.852 0 0 0-4.847-4.846 4.852 4.852 0 0 0-4.846 4.846 4.852 4.852 0 0 0 4.846 4.847 4.852 4.852 0 0 0 4.847-4.847zm5.538 9c0 .758-.627 1.385-1.385 1.385-.367 0-.724-.151-.973-.411l-3.71-3.7a7.598 7.598 0 0 1-4.317 1.342A7.613 7.613 0 0 1 3 10.615 7.613 7.613 0 0 1 10.615 3a7.613 7.613 0 0 1 7.616 7.615c0 1.536-.465 3.05-1.342 4.316l3.71 3.71c.25.25.401.607.401.974z" fill="#0055D9">
#              </path>
#             </svg>
#            </i>
#           </span>
#           <style data-emotion="css ukkbbr">
#            .css-ukkbbr{color:#0D2955;background-color:#FAFAFB;border:1px solid;border-radius:2px;border-color:#D9DDE4;width:100%;letter-spacing:-0.47px;line-height:20px;font-size:15px;-webkit-transition:color .2s ease,background-color .2s ease,border-color .2s ease,box-shadow .2s ease;transition:color .2s ease,background-color .2s ease,border-color .2s ease,box-shadow .2s ease;padding:10px 8px;height:40px;padding-left:32px;border:none;padding-left:44px;background-color:#ffffff;position:relative;}.css-ukkbbr::-webkit-input-placeholder{color:#808EA5;}.css-ukkbbr::-moz-placeholder{color:#808EA5;}.css-ukkbbr::-webkit-input-placeholder{color:#808EA5;}.css-ukkbbr::-moz-placeholder{color:#808EA5;}.css-ukkbbr:-ms-input-placeholder{color:#808EA5;}.css-ukkbbr::placeholder{color:#808EA5;}.css-ukkbbr:hover{border-color:#BFC6D2;}.css-ukkbbr:focus{outline:none;border-color:#4D93FF;box-shadow:rgba(0, 0, 0, 0.075) 0px 1px 1px inset,rgba(0, 126, 255, 0.1) 0px 0px 0px 3px;}.css-ukkbbr:disabled{cursor:not-allowed;border-color:#D9DDE4;opacity:0.5;}.css-ukkbbr:focus{box-shadow:none;background-color:#ffffff;}.css-ukkbbr::-webkit-input-placeholder{font-size:20px;font-weight:200;}.css-ukkbbr::-moz-placeholder{font-size:20px;font-weight:200;}.css-ukkbbr:-ms-input-placeholder{font-size:20px;font-weight:200;}.css-ukkbbr::placeholder{font-size:20px;font-weight:200;}@media screen and (max-width: 991px){.css-ukkbbr::-webkit-input-placeholder{font-size:14px;}.css-ukkbbr::-moz-placeholder{font-size:14px;}.css-ukkbbr:-ms-input-placeholder{font-size:14px;}.css-ukkbbr::placeholder{font-size:14px;}}
#           </style>
#           <input autocomplete="false" class="css-ukkbbr e1n2h7jb1" enterkeyhint="search" name="q" placeholder="Search Jobs (e.g. Sales in Maadi)" value=""/>
#          </div>
#          <style data-emotion="css 1aw6xt7">
#           .css-1aw6xt7{position:absolute;right:175px;top:33%;font-size:18px;font-weight:300;color:#031431;}@media screen and (max-width: 991px){.css-1aw6xt7{display:none;}}
#          </style>
#          <span class="css-1aw6xt7">
#           8,453
#           <!-- -->
#           Open Jobs
#          </span>
#          <style data-emotion="css wzb396">
#           .css-wzb396{padding-inline:24px;border-radius:3px;height:48px;font-size:18px;}@media screen and (max-width: 991px){.css-wzb396{display:none;}}
#          </style>
#          <style data-emotion="css 11qi1o">
#           .css-11qi1o{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:15px;padding:0 12px;border:1px solid transparent;border-radius:2px;-webkit-text-decoration:none;text-decoration:none;text-align:center;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;cursor:pointer;min-width:80px;-webkit-transition:color .2s ease,background-color .2s ease,border-color .2s ease;transition:color .2s ease,background-color .2s ease,border-color .2s ease;min-height:40px;line-height:32px;color:#ffffff;background-color:#0055D9;padding-inline:24px;border-radius:3px;height:48px;font-size:18px;}.css-11qi1o:focus{outline:none;}.css-11qi1o:disabled{opacity:0.25;cursor:not-allowed;}.css-11qi1o:hover{background-color:#0046B2;}.css-11qi1o:active{background-color:#00327F;}.css-11qi1o:focus{border-color:#80B2FF;}.css-11qi1o:disabled:hover{background-color:#0055D9;}@media screen and (max-width: 991px){.css-11qi1o{display:none;}}
#          </style>
#          <button class="css-11qi1o ezfki8j0" type="submit">
#           Search Jobs
#          </button>
#         </form>
#        </div>
#        <style data-emotion="css zbidvu animation-1kuzypk">
#         .css-zbidvu{border:2px solid white;width:48px;height:48px;border-radius:50%;position:absolute;bottom:40px;left:calc(50% - 24px);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;cursor:pointer;-webkit-animation:animation-1kuzypk 2.5s ease-out infinite;animation:animation-1kuzypk 2.5s ease-out infinite;z-index:999;}@-webkit-keyframes animation-1kuzypk{from,20%,53%,80%,to{-webkit-transform:translate3d(0,0,0);-moz-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);}40%,43%{-webkit-transform:translate3d(0, -30px, 0);-moz-transform:translate3d(0, -30px, 0);-ms-transform:translate3d(0, -30px, 0);transform:translate3d(0, -30px, 0);}70%{-webkit-transform:translate3d(0, -15px, 0);-moz-transform:translate3d(0, -15px, 0);-ms-transform:translate3d(0, -15px, 0);transform:translate3d(0, -15px, 0);}90%{-webkit-transform:translate3d(0,-4px,0);-moz-transform:translate3d(0,-4px,0);-ms-transform:translate3d(0,-4px,0);transform:translate3d(0,-4px,0);}}@keyframes animation-1kuzypk{from,20%,53%,80%,to{-webkit-transform:translate3d(0,0,0);-moz-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);}40%,43%{-webkit-transform:translate3d(0, -30px, 0);-moz-transform:translate3d(0, -30px, 0);-ms-transform:translate3d(0, -30px, 0);transform:translate3d(0, -30px, 0);}70%{-webkit-transform:translate3d(0, -15px, 0);-moz-transform:translate3d(0, -15px, 0);-ms-transform:translate3d(0, -15px, 0);transform:translate3d(0, -15px, 0);}90%{-webkit-transform:translate3d(0,-4px,0);-moz-transform:translate3d(0,-4px,0);-ms-transform:translate3d(0,-4px,0);transform:translate3d(0,-4px,0);}}
#        </style>
#        <div class="css-zbidvu">
#         <style data-emotion="css 16r7llb">
#          .css-16r7llb{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;line-height:1em;width:24px;height:24px;}
#         </style>
#         <i class="css-16r7llb efou2fk0" size="24">
#          <svg height="24" preserveaspectratio="none" viewbox="0 0 24 24" width="24">
#           <path d="M17.355 7.5L12 13.063 6.645 7.5 5 9.213l7 7.287 7-7.287z" fill="#ffffff">
#           </path>
#          </svg>
#         </i>
#        </div>
#       </div>
#       <style data-emotion="css 195auf1">
#        .css-195auf1{height:100vh;position:relative;}
#       </style>
#       <div class="css-195auf1">
#        <style data-emotion="css pwse4w">
#         .css-pwse4w{position:absolute;top:0;object-fit:cover;z-index:0;will-change:opacity;height:100%;width:100%;opacity:1;}
#        </style>
#        <img alt="Woman open her laptop and finding suitable job through WUZZUF" class="css-pwse4w" height="1000" loading="lazy" role="presentation" src="https://static.wuzzuf-data.net/d83b7756eddae9c7145581d6fe1884e2.webp?height=1000&amp;width=1000" srcset="https://static.wuzzuf-data.net/74910bb8bb34cb642563867a655e4b93.webp 300w, https://static.wuzzuf-data.net/d83b7756eddae9c7145581d6fe1884e2.webp 1000w, https://static.wuzzuf-data.net/0387946f117b6b77686b149d0b0bf39d.webp 1441w" style="opacity:0;transition:opacity 0.2s ease-in-out" width="1000"/>
#       </div>
#       <style data-emotion="css 1vcob1d">
#        .css-1vcob1d{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
#       </style>
#       <div class="css-1vcob1d">
#        <style data-emotion="css-global 1o7rbkm">
#         .slick-arrow{color:#0046B2;box-shadow:none!important;border:none!important;}.slick-next{top:50%!important;right:-20px!important;}.slick-prev{color:#0046B2;top:50%!important;left:-45px!important;}@media screen and (max-width: 1039px){.slick-next{right:-40px!important;}}.slick-track>div{margin:0px;}.slick-slider{position:static!important;}.slick-dots{bottom:unset;}
#        </style>
#        <style data-emotion="css 19bmlml">
#         .css-19bmlml{padding-top:40px;padding-bottom:80px;}@media screen and (max-width: 1159px){.css-19bmlml{padding:40px 0;}}
#        </style>
#        <div class="css-19bmlml">
#         <style data-emotion="css 18y3zhy">
#          .css-18y3zhy{text-align:center;margin-bottom:40px;}
#         </style>
#         <div class="css-18y3zhy">
#          <style data-emotion="css 1yu7uye">
#           .css-1yu7uye{font-weight:300;font-size:30px;color:#4D6182;}@media screen and (max-width: 1040px){.css-1yu7uye{font-weight:600;font-size:20px;}}
#          </style>
#          <h2 class="css-1yu7uye">
#           Join Egypt's Top Companies
#          </h2>
#         </div>
#         <style data-emotion="css 75uuf2">
#          .css-75uuf2{width:940px;position:relative;}@media screen and (max-width: 1040px){.css-75uuf2{display:none;}}
#         </style>
#         <div class="css-75uuf2">
#          <div class="slick-slider slick-initialized" dir="ltr">
#           <style data-emotion="css flxqo6">
#            .css-flxqo6{width:32px;height:32px;border-radius:50%;top:50%;background:#ffffff!important;cursor:pointer;box-shadow:0px 1px 3px 0px rgba(0, 0, 0, 0.1);display:-webkit-inline-box!important;display:-webkit-inline-flex!important;display:-ms-inline-flexbox!important;display:inline-flex!important;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;position:absolute;z-index:1;left:-14px;}.css-flxqo6:before{display:none;}@media(max-width: 575px){.css-flxqo6{display:none!important;}}
#           </style>
#           <button class="slick-arrow slick-prev css-flxqo6" currentslide="0" data-role="none" slidecount="8" style="display:block">
#            <style data-emotion="css b80bsd">
#             .css-b80bsd{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;line-height:1em;width:16px;height:16px;}
#            </style>
#            <i class="css-b80bsd efou2fk0" size="16">
#             <svg height="16" preserveaspectratio="none" viewbox="0 0 24 24" width="16">
#              <path d="M14.787 19l1.713-1.645L10.937 12 16.5 6.645 14.787 5 7.5 12z" fill="#0055D9">
#              </path>
#             </svg>
#            </i>
#           </button>
#           <div class="slick-list">
#            <div class="slick-track" style="width:1700%;left:-100%">
#             <div aria-hidden="true" class="slick-slide slick-cloned" data-index="-1" style="width:5.882352941176471%" tabindex="-1">
#             </div>
#             <div aria-hidden="false" class="slick-slide slick-active slick-current" data-index="0" style="outline:none;width:5.882352941176471%" tabindex="-1">
#              <div>
#               <div style="width:100%;display:inline-block" tabindex="-1">
#                <style data-emotion="css i7yi7v">
#                 .css-i7yi7v{display:grid;grid-template-columns:repeat(9,1fr);grid-template-rows:repeat(2,1fr);height:auto;grid-auto-rows:auto auto;}.css-i7yi7v>*:nth-child(odd){border-right:none;}.css-i7yi7v>*:nth-child(2n+2){border-right:none;}.css-i7yi7v>*:nth-child(-n+4){border-bottom:none;}.css-i7yi7v>*:nth-child(1),.css-i7yi7v>*:nth-child(5){border-left:1px solid #EBEDF0;}
#                </style>
#                <div class="css-i7yi7v">
#                 <style data-emotion="css 9h2ihk">
#                  .css-9h2ihk{border:1px solid #EBEDF0;cursor:pointer;padding:16px;width:230px;max-height:120px;}
#                 </style>
#                 <a class="css-9h2ihk" href="/jobs/careers/Talaat-Moustafa-Group-Egypt-3106" style="grid-column:1 / 3" title="Talaat Moustafa Group">
#                  <style data-emotion="css 1e44589">
#                   .css-1e44589{width:100%;max-height:65px;object-fit:contain;max-width:155px;margin:auto;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
#                  </style>
#                  <img alt="Talaat Moustafa Group" class="css-1e44589" height="155" loading="lazy" src="https://images.wuzzuf-data.net/files/company_logo/featured_logo/featured-logo-3106-1734601585.png?height=155&amp;width=155" style="opacity:0;transition:opacity 0.2s ease-in-out" width="155"/>
#                 </a>
#                 <a class="css-9h2ihk" href="/jobs/careers/Elabd-Foods-Egypt-7864" style="grid-column:3 / 5" title="Elabd Foods">
#                  <img alt="Elabd Foods" class="css-1e44589" height="155" loading="lazy" src="https://images.wuzzuf-data.net/files/company_logo/featured_logo/featured-logo-7864-1472140989-backup.png?height=155&amp;width=155" style="opacity:0;transition:opacity 0.2s ease-in-out" width="155"/>
#                 </a>
#                 <a class="css-9h2ihk" href="/jobs/careers/Etisalat-Misr-Egypt-4219" style="grid-column:5 / 7" title="Etisalat Egypt">
#                  <img alt="Etisalat Egypt" class="css-1e44589" height="155" loading="lazy" src="https://images.wuzzuf-data.net/files/company_logo/featured_logo/featured-logo-4219-1693993786.png?height=155&amp;width=155" style="opacity:0;transition:opacity 0.2s ease-in-out" width="155"/>
#                 </a>
#                 <a class="css-9h2ihk" href="/jobs/careers/Amreyah-Cement---InterCement-Egypt-11531" style="grid-column:7 / 9;border-right:1px solid #EBEDF0" title="Amreyah Cement">
#                  <img alt="Amreyah Cement" class="css-1e44589" height="155" loading="lazy" src="https://images.wuzzuf-data.net/files/company_logo/featured_logo/featured-logo-11531-1736689756.png?height=155&amp;width=155" style="opacity:0;transition:opacity 0.2s ease-in-out" width="155"/>
#                 </a>
#                 <style data-emotion="css y4ey34">
#                  .css-y4ey34{border:1px solid #EBEDF0;cursor:pointer;padding:16px;width:115px;max-height:80px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
#                 </style>
#                 <a class="css-y4ey34" href="/jobs/careers/VOIS-Egypt-Egypt-967" style="grid-row:2 / 2;grid-column:1 / 2" title="VOIS Egypt">
#                  <style data-emotion="css 177a74q">
#                   .css-177a74q{width:100%;max-height:80px;height:100%;}
#                  </style>
#                  <img alt="VOIS Egypt" class="css-177a74q" height="155" loading="lazy" src="https://images.wuzzuf-data.net/files/company_logo/featured_logo/featured-logo-967-1734521517.png?height=155&amp;width=155" style="opacity:0;transition:opacity 0.2s ease-in-out" width="155"/>
#                 </a>
#                 <a class="css-y4ey34" href="/jobs/careers/Premium-Card-Egypt-766" style="grid-row:2 / 2;grid-column:2 / 3" title="Premium Card">
#                  <img alt="Premium Card" class="css-177a74q" height="155" loading="lazy" src="https://images.wuzzuf-data.net/files/company_logo/featured_logo/featured-logo-766-1531653851.png?height=155&amp;width=155" style="opacity:0;transition:opacity 0.2s ease-in-out" width="155"/>
#                 </a>
#                 <a class="css-y4ey34" href="/jobs/careers/Dakahlia-Group-Egypt-4638" style="grid-row:2 / 2;grid-column:3 / 4" title="Dakahlia Group">
#                  <img alt="Dakahlia Group" class="css-177a74q" height="155" loading="lazy" src="https://images.wuzzuf-data.net/files/company_logo/featured_logo/featured-logo-4638-1595757998.png?height=155&amp;width=155" style="opacity:0;transition:opacity 0.2s ease-in-out" width="155"/>
#                 </a>
#                 <a class="css-y4ey34" href="/jobs/careers/As-Salam-International-Hospital-Egypt-11392" style="grid-row:2 / 2;grid-column:4 / 5" title="As-Salam International Hospital">
#                  <img alt="As-Salam International Hospital" class="css-177a74q" height="155" loading="lazy" src="https://images.wuzzuf-data.net/files/company_logo/featured_logo/featured-logo-11392-1507547542.png?height=155&amp;width=155" style="opacity:0;transition:opacity 0.2s ease-in-out" width="155"/>
#                 </a>
#                 <a class="css-y4ey34" href="/jobs/careers/Dynamicslink-Egypt-21303" style="grid-row:2 / 2;grid-column:5 / 6" title="Dynamicslink">
#                  <img alt="Dynamicslink" class="css-177a74q" height="155" loading="lazy" src="https://images.wuzzuf-data.net/files/company_logo/featured_logo/featured-logo-21303-1482070010.png?height=155&amp;width=155" style="opacity:0;transition:opacity 0.2s ease-in-out" width="155"/>
#                 </a>
#                 <a class="css-y4ey34" href="/jobs/careers/Dawi-Clinics-Egypt-22444" style="grid-row:2 / 2;grid-column:6 / 7" title="Dawi Clinics">
#                  <img alt="Dawi Clinics" class="css-177a74q" height="155" loading="lazy" src="https://images.wuzzuf-data.net/files/company_logo/featured_logo/featured-logo-22444-1524568215.png?height=155&amp;width=155" style="opacity:0;transition:opacity 0.2s ease-in-out" width="155"/>
#                 </a>
#                 <a class="css-y4ey34" href="/jobs/careers/surgitech-Egypt-6193" style="grid-row:2 / 2;grid-column:7 / 8" title="Surgitech ">
#                  <img alt="Surgitech " class="css-177a74q" height="155" loading="lazy" src="https://images.wuzzuf-data.net/files/company_logo/featured_logo/featured-logo-6193-1724150735.png?height=155&amp;width=155" style="opacity:0;transition:opacity 0.2s ease-in-out" width="155"/>
#                 </a>
#                 <a class="css-y4ey34" href="/jobs/careers/Target-Engineering-Egypt-23128" style="grid-row:2 / 2;grid-column:8 / 9;border-right:1px solid #EBEDF0" title="Target Engineering">
#                  <img alt="Target Engineering" class="css-177a74q" height="155" loading="lazy" src="https://images.wuzzuf-data.net/files/company_logo/featured_logo/featured-logo-23128-1488814953.png?height=155&amp;width=155" style="opacity:0;transition:opacity 0.2s ease-in-out" width="155"/>
#                 </a>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div aria-hidden="true" class="slick-slide" data-index="1" style="outline:none;width:5.882352941176471%" tabindex="-1">
#             </div>
#             <div aria-hidden="true" class="slick-slide" data-index="2" style="outline:none;width:5.882352941176471%" tabindex="-1">
#             </div>
#             <div aria-hidden="true" class="slick-slide" data-index="3" style="outline:none;width:5.882352941176471%" tabindex="-1">
#             </div>
#             <div aria-hidden="true" class="slick-slide" data-index="4" style="outline:none;width:5.882352941176471%" tabindex="-1">
#             </div>
#             <div aria-hidden="true" class="slick-slide" data-index="5" style="outline:none;width:5.882352941176471%" tabindex="-1">
#             </div>
#             <div aria-hidden="true" class="slick-slide" data-index="6" style="outline:none;width:5.882352941176471%" tabindex="-1">
#             </div>
#             <div aria-hidden="true" class="slick-slide" data-index="7" style="outline:none;width:5.882352941176471%" tabindex="-1">
#             </div>
#             <div aria-hidden="true" class="slick-slide slick-cloned" data-index="8" style="width:5.882352941176471%" tabindex="-1">
#              <div>
#               <div style="width:100%;display:inline-block" tabindex="-1">
#                <div class="css-i7yi7v">
#                 <a class="css-9h2ihk" href="/jobs/careers/Talaat-Moustafa-Group-Egypt-3106" style="grid-column:1 / 3" title="Talaat Moustafa Group">
#                  <img alt="Talaat Moustafa Group" class="css-1e44589" height="155" loading="lazy" src="https://images.wuzzuf-data.net/files/company_logo/featured_logo/featured-logo-3106-1734601585.png?height=155&amp;width=155" style="opacity:0;transition:opacity 0.2s ease-in-out" width="155"/>
#                 </a>
#                 <a class="css-9h2ihk" href="/jobs/careers/Elabd-Foods-Egypt-7864" style="grid-column:3 / 5" title="Elabd Foods">
#                  <img alt="Elabd Foods" class="css-1e44589" height="155" loading="lazy" src="https://images.wuzzuf-data.net/files/company_logo/featured_logo/featured-logo-7864-1472140989-backup.png?height=155&amp;width=155" style="opacity:0;transition:opacity 0.2s ease-in-out" width="155"/>
#                 </a>
# ...
#         <style data-emotion="css 1xlu65a">
#          .css-1xlu65a{-webkit-columns:2;columns:2;-webkit-column-count:2;column-count:2;}
#         </style>
#         <div class="css-1xlu65a">
#          <style data-emotion="css uwrdmv">
#           .css-uwrdmv{padding-top:8px;color:white;display:block;-webkit-text-decoration:none;text-decoration:none;}.css-uwrdmv:hover{-webkit-text-decoration:underline;text-decoration:underline;}
#          </style>
#          <a aria-label="navigate to wuzzuf blog" class="css-uwrdmv e135gsrz3" href="http://blog.wuzzuf.net/" rel="noopener noreferrer" target="_blank">
#           Blog
#          </a>
#          <a aria-label="navigate to about us" class="css-uwrdmv e135gsrz2" href="/about-us">
#           About Us
#          </a>
#          <a aria-label="navigate to employer home page" class="css-uwrdmv e135gsrz2" href="/recruitment/egypt">
#           Recruitment Services
#          </a>
#          <a aria-label="navigate to wuzzuf feeds" class="css-uwrdmv e135gsrz3" href="https://wuzzuf.net/feeds/all-jobs.xml">
#           RSS
#          </a>
#          <a aria-label="navigate to Jobs in Saudi Arabia job" class="css-uwrdmv e135gsrz3" href="https://wuzzuf.net/saudi/jobs">
#           Jobs in Saudi Arabia
#          </a>
#          <a aria-label="navigate to Jobs in UAE job" class="css-uwrdmv e135gsrz3" href="https://wuzzuf.net/a/jobs-in-United%20Arab%20Emirates">
#           Jobs in UAE
#          </a>
#          <a aria-label="navigate to wuzzuf Job Descriptions" class="css-uwrdmv e135gsrz2" href="/job-descriptions">
#           Job Descriptions
#          </a>
#          <a aria-label="navigate to wuzzuf partners" class="css-uwrdmv e135gsrz2" href="/partners">
#           Partners
#          </a>
#          <a aria-label="navigate to wuzzuf sitemap " class="css-uwrdmv e135gsrz3" href="https://wuzzuf.net/sitemap-updates">
#           Sitemap
#          </a>
#          <a aria-label="navigate to wuzzuf contact us" class="css-uwrdmv e135gsrz3" href="https://wuzzuf.net/contact-us">
#           Contact Us
#          </a>
#          <a aria-label="navigate to wuzzuf policies" class="css-uwrdmv e135gsrz2" href="/policies">
#           Privacy, Cookies, Terms &amp; Conditions
#          </a>
#          <a aria-label="navigate to forasna home page" class="css-uwrdmv e135gsrz3" href="http://forasna.com/jobs/egypt" rel="noopener noreferrer" target="_blank">
#           وظائف مصر
#          </a>
#         </div>
#        </section>
#        <style data-emotion="css 1t8pxvs">
#         .css-1t8pxvs{-webkit-flex:3;-ms-flex:3;flex:3;padding-right:50px;margin-bottom:32px;}
#        </style>
#        <section class="css-1t8pxvs">
#         <style data-emotion="css 1s22u92">
#          .css-1s22u92{margin-bottom:32px;}
#         </style>
#         <div class="css-1s22u92">
#          <style data-emotion="css 1m2yams">
#           .css-1m2yams{font-weight:600;margin-top:0;margin-bottom:8px;font-size:18px;}
#          </style>
#          <p class="css-1m2yams">
#           Follow Us
#          </p>
#          <style data-emotion="css 74n2tq">
#           .css-74n2tq{padding-top:12px;}
#          </style>
#          <div class="css-74n2tq">
#           <a aria-label="wuzzuf facebook social page link" href="https://www.facebook.com/wuzzuf" rel="noopener noreferrer" target="_blank">
#            <style data-emotion="css nkt64x">
#             .css-nkt64x{margin-right:10px;}
#            </style>
#            <style data-emotion="css 1isj61a">
#             .css-1isj61a{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;line-height:1em;width:28px;height:28px;margin-right:10px;}
#            </style>
#            <i class="e135gsrz0 css-1isj61a efou2fk0" size="28">
#             <svg height="28" preserveaspectratio="none" viewbox="0 0 24 24" width="28">
#              <path d="M16.261 4.113v2.525l-1.498.004c-1.175 0-1.401.558-1.401 1.374v1.806h2.798l-.363 2.826h-2.435V20h-2.919v-7.352H8V9.822h2.443V7.74C10.443 5.319 11.918 4 14.08 4c1.03 0 1.92.078 2.181.113z" fill="white">
#              </path>
#             </svg>
#            </i>
#           </a>
#           <a aria-label="wuzzuf twitter social page link" href="https://twitter.com/wuzzuf" rel="noopener noreferrer" target="_blank">
#            <i class="e135gsrz0 css-1isj61a efou2fk0" size="28">
#             <svg height="28" preserveaspectratio="none" viewbox="0 0 24 24" width="28">
#              <path d="M18.362 8.572c.207 4.617-3.235 9.764-9.33 9.764A9.291 9.291 0 014 16.861a6.6 6.6 0 004.86-1.36 3.285 3.285 0 01-3.066-2.279c.514.099 1.02.07 1.482-.055-1.58-.318-2.669-1.74-2.633-3.26.442.245.949.393 1.487.41a3.286 3.286 0 01-1.016-4.383 9.318 9.318 0 006.766 3.43c-.479-2.054 1.079-4.03 3.197-4.03.945 0 1.798.398 2.396 1.036a6.565 6.565 0 002.085-.797 3.289 3.289 0 01-1.443 1.816A6.556 6.556 0 0020 6.872a6.664 6.664 0 01-1.638 1.7" fill="white">
#              </path>
#             </svg>
#            </i>
#           </a>
#           <a aria-label="wuzzuf linkedin social page link" href="https://www.linkedin.com/company/wuzzuf-com" rel="noopener noreferrer" target="_blank">
#            <i class="e135gsrz0 css-1isj61a efou2fk0" size="28">
#             <svg height="28" preserveaspectratio="none" viewbox="0 0 24 24" width="28">
#              <path d="M20 20h-3.288v-5.6c0-1.535-.583-2.392-1.798-2.392-1.322 0-2.012.892-2.012 2.393V20H9.733V9.333h3.169v1.437s.952-1.763 3.216-1.763c2.262 0 3.882 1.382 3.882 4.24V20zM5.954 7.937A1.961 1.961 0 014 5.968C4 4.881 4.874 4 5.954 4a1.96 1.96 0 011.953 1.968 1.96 1.96 0 01-1.953 1.969zM4.318 20H7.62V9.333H4.318V20z" fill="white">
#              </path>
#             </svg>
#            </i>
#           </a>
#           <a aria-label="wuzzuf youtube social page link" href="https://www.youtube.com/wuzzuf" rel="noopener noreferrer" target="_blank">
#            <i class="e135gsrz0 css-1isj61a efou2fk0" size="28">
#             <svg height="28" preserveaspectratio="none" viewbox="0 0 24 24" width="28">
#              <path d="M10.348 14.213V9.419l4.322 2.405-4.322 2.389zm9.492-5.624s-.157-1.176-.636-1.694c-.608-.68-1.29-.683-1.603-.722C15.362 6 12.004 6 12.004 6h-.008S8.638 6 6.4 6.173c-.313.04-.995.042-1.604.722-.479.518-.635 1.694-.635 1.694S4 9.969 4 11.349v1.295c0 1.381.16 2.762.16 2.762s.156 1.175.635 1.693c.61.68 1.409.658 1.765.73C7.84 17.958 12 18 12 18s3.362-.005 5.601-.178c.313-.04.995-.043 1.603-.723.48-.518.636-1.693.636-1.693s.16-1.38.16-2.762V11.35c0-1.38-.16-2.761-.16-2.761z" fill="white">
#              </path>
#             </svg>
#            </i>
#           </a>
#          </div>
#         </div>
#         <style data-emotion="css 8xph5n">
#          .css-8xph5n{font-size:12px;line-height:16px;font-weight:400;}
#         </style>
#         <span class="css-8xph5n">
#          ©
#          <!-- -->
#          2025
#          <!-- -->
#          WUZZUF. All Rights Reserved. Owned by
#          <!-- -->
#          <style data-emotion="css 220rkc">
#           .css-220rkc{color:#fff;}
#          </style>
#          <a aria-label="basharsoft page" class="css-220rkc" href="https://www.basharsoft.com/" rel="noopener noreferrer" target="_blank">
#           BasharSoft LLC.
#          </a>
#         </span>
#        </section>
#       </div>
#      </footer>
#     </div>
#    </div>
#   </div>
#   <script>
#    (function(){
#             var Wuzzuf = window.Wuzzuf = window.Wuzzuf || {};
#             Wuzzuf.country = {"country":"Egypt","countryId":"","subFolder":"","subFolderName":"egypt","defaultCountryQueryParams":"","capital":"Cairo","jobseekerHomePage":"\u002Fjobs\u002Fegypt","empHomePage":"\u002Frecruitment\u002Fegypt","hrefLang":"en-EG","viewerCountryIso":"eg"};
#             Wuzzuf.headers = {"host":"wuzzuf.net","x-request-id":"ba98152f411d4636cb220ab65c385709","x-real-ip":"41.239.156.63","x-forwarded-for":"41.239.156.63","x-forwarded-host":"wuzzuf.net","x-forwarded-port":"80","x-forwarded-proto":"http","x-forwarded-scheme":"http","x-scheme":"http","x-original-forwarded-for":"41.239.156.63, 64.252.88.209","x-amzn-trace-id":"Root=1-67bb385c-57b1f26c3590406520e2b4ea","user-agent":"Amazon CloudFront","x-amz-cf-id":"AKyMovoBUdrG0kKt0xRECnpUrimCOzRp_np2B2QQqHKl_QM3yHQJGQ==","if-none-match":"W\u002F\"69a39-MJVQ0uNnFSSKl\u002FBOCok50\u002Fy4Oys\"","via":"2.0 9e1ca2a082cf3304834fbd01d8598ce4.cloudfront.net (CloudFront)","accept-encoding":"gzip","sec-ch-ua":"\"Not(A:Brand\";v=\"99\", \"Google Chrome\";v=\"133\", \"Chromium\";v=\"133\"","sec-ch-ua-mobile":"?1","sec-ch-ua-platform":"\"Android\"","upgrade-insecure-requests":"1","sec-fetch-site":"cross-site","sec-fetch-mode":"navigate","sec-fetch-user":"?1","sec-fetch-dest":"document","priority":"u=0, i"};
#             Wuzzuf.isServerRendered = true;
#             Wuzzuf.initialStoreState = {"badges":{"landingPage":{"timestamp":null,"providers":null,"loading":false}},"browsingPage":{"sets":{},"metaTemplateType":{}},"communityPages":{"internship":{"jobs":{},"filters":{"isLoading":true,"isError":false,"error":null,"sets":{}},"hotJobs":null},"alexandria":{"jobs":{},"filters":{"isLoading":true,"isError":false,"error":null,"sets":{}},"hotJobs":null},"android":{"jobs":{},"filters":{"isLoading":true,"isError":false,"error":null,"sets":{}},"hotJobs":null},"pharmaceutical":{"jobs":{},"filters":{"isLoading":true,"isError":false,"error":null,"sets":{}},"hotJobs":null},"workFromHome":{"jobs":{},"filters":{"isLoading":true,"isError":false,"error":null,"sets":{}},"hotJobs":null},"startups":{"jobs":{},"filters":{"isLoading":true,"isError":false,"error":null,"sets":{}},"hotJobs":null}},"entities":{"companyPlanBenefit":{"isLoading":false,"collection":{},"error":null,"timestamp":null},"applicationStatistics":{"isLoading":false,"collection":{},"error":null,"timestamp":null},"badge":{"isLoading":false,"collection":{},"error":null,"timestamp":null},"badgeGradeDetails":{"isLoading":false,"collection":{},"error":null,"timestamp":null},"company":{"collection":{"403":{"id":"403","type":"company","attributes":{"uniqueId":"c694d328-9373-11ea-add1-062a4819e772","name":"B.TECH","legalName":null,"logo":"B-Tech-Egypt-403-1645525431.png","slug":"B-Tech-Egypt-403","description":"B.TECH is an Egyptian shareholding company; founded in 1997, and is the largest retailer specialized in trading and distributing home appliances and electronics in the Arab Republic of Egypt. We take pride in bringing the latest technologies and financial solutions to our customers everyday. ","specialties":[],"hiringFor":null,"website":"https:\u002F\u002Fbtech.com\u002F","facebookPage":null,"twitterAccount":null,"linkedinProfile":null,"blog":null,"onlinePresence":{"facebook":null,"twitter":null,"linkedin":null,"blog":null,"website":"https:\u002F\u002Fbtech.com\u002F","instagram":null,"youtube":null,"vimeo":null,"behance":null},"establishedYear":"","uniqueName":"B.TECH -w- 403","taxId":null,"street":"-","isPersonal":false,"buildingNumber":"-","area":"-","publicStatus":{"id":1,"name":"Verified"},"statusUpdatedAt":null,"createdAt":"05\u002F22\u002F2012 21:17:28","perks":[]},"links":{"self":"https:\u002F\u002Fwuzzuf.net\u002Fapi\u002Fcompany\u002F403","defaultLogoUrl":"https:\u002F\u002Fimages.wuzzuf-data.net\u002Ffiles\u002Fcompany_logo\u002FB-Tech-Egypt-403-1645525431.png","orgLogoUrl":"https:\u002F\u002Fimages.wuzzuf-data.net\u002Ffiles\u002Fcompany_logo\u002FB-Tech-Egypt-403-1645525431-org.png","smLogoUrl":"https:\u002F\u002Fimages.wuzzuf-data.net\u002Ffiles\u002Fcompany_logo\u002FB-Tech-Egypt-403-1645525431-sm.png","xsLogoUrl":"https:\u002F\u002Fimages.wuzzuf-data.net\u002Ffiles\u002Fcompany_logo\u002FB-Tech-Egypt-403-1645525431-xs.png","ogLogoUrl":"https:\u002F\u002Fimages.wuzzuf-data.net\u002Ffiles\u002Fcompany_logo\u002FB-Tech-Egypt-403-1645525431-og.png","defaultCoverUrl":"https:\u002F\u002Fimages.wuzzuf-data.net\u002Ffiles\u002Fcompany_covers\u002F559727436642e877d43e80.png","coverUrl":"https:\u002F\u002Fimages.wuzzuf-data.net\u002Ffiles\u002Fcompany_covers\u002Fthumbs\u002F559727436642e877d43e80.png","profile":"jobs\u002Fcareers\u002FB-Tech-Egypt-403"},"relationships":{"workIndustries":{"data":[{"id":"158770","type":"companyWorkIndustry"}]},"featuredLogos":{"data":[{"id":"968","type":"companyFeaturedLogo"}]},"country":{"data":{"id":"56","type":"country"}},"city":{"data":{"id":"1545","type":"city"}},"size":{"data":{"id":"6","type":"companySize"}},"type":{"data":null}}},"766":{"id":"766","type":"company","attributes":{"uniqueId":"c69716af-9373-11ea-add1-062a4819e772","name":"Premium Card","legalName":null,"logo":"17463337946728b1e9bb788.png","slug":"Premium-Card-Egypt-766","description":"Premium Card for Financial Services established an interest-free credit card, with a payment plan over 10  months","specialties":[],"hiringFo ...
#             Wuzzuf.serverRenderedURL = "/jobs/egypt";
#             Wuzzuf.userType = "guest";
#         }());
#   </script>
#   <script>
#    window.addEventListener('beforeinstallprompt', function(){
#             e.preventDefault();
#         });
#   </script>
#   <script id="__LOADABLE_REQUIRED_CHUNKS__" type="application/json">
#    [7791,7603,4571,6334,5798,2195,7583,7863,9825,4772,3411,7740,5872,4012,1452]
#   </script>
#   <script id="__LOADABLE_REQUIRED_CHUNKS___ext" type="application/json">
#    {"namedChunks":["guest-jobseeker-landing-page-egypt"]}
#   </script>
#   <script data-chunk="index" defer="" src="https://static.wuzzuf-data.net/vendor-1740310555633.c0359e6c4dac3e799e4a.js">
#   </script>
#   <script data-chunk="index" defer="" src="https://static.wuzzuf-data.net/index-1740310555633.9c41399101f237ae6e98.js">
#   </script>
#   <script data-chunk="guest-jobseeker-landing-page-egypt" defer="" src="https://static.wuzzuf-data.net/7791-1740310555633.686a2b14b15273dfb473.js">
#   </script>
#   <script data-chunk="guest-jobseeker-landing-page-egypt" defer="" src="https://static.wuzzuf-data.net/7603-1740310555633.3dd87b0daa5eaf99ac5e.js">
#   </script>
#   <script data-chunk="guest-jobseeker-landing-page-egypt" defer="" src="https://static.wuzzuf-data.net/4571-1740310555633.ed7c0975286ae8763afa.js">
#   </script>
#   <script data-chunk="guest-jobseeker-landing-page-egypt" defer="" src="https://static.wuzzuf-data.net/6334-1740310555633.b136bb51d8bbf27e9545.js">
#   </script>
#   <script data-chunk="guest-jobseeker-landing-page-egypt" defer="" src="https://static.wuzzuf-data.net/5798-1740310555633.be580ee938f216ec6ca7.js">
#   </script>
#   <script data-chunk="guest-jobseeker-landing-page-egypt" defer="" src="https://static.wuzzuf-data.net/2195-1740310555633.c1624b79ae60153308a3.js">
#   </script>
#   <script data-chunk="guest-jobseeker-landing-page-egypt" defer="" src="https://static.wuzzuf-data.net/7583-1740310555633.99b30fb54aecc12fbcae.js">
#   </script>
#   <script data-chunk="guest-jobseeker-landing-page-egypt" defer="" src="https://static.wuzzuf-data.net/7863-1740310555633.5bb0bf26d64a72649bb8.js">
#   </script>
#   <script data-chunk="guest-jobseeker-landing-page-egypt" defer="" src="https://static.wuzzuf-data.net/guest-footer-1740310555633.7194506b1fe664702440.js">
#   </script>
#   <script data-chunk="guest-jobseeker-landing-page-egypt" defer="" src="https://static.wuzzuf-data.net/4772-1740310555633.f978e49fd86fa2049ba0.js">
#   </script>
#   <script data-chunk="guest-jobseeker-landing-page-egypt" defer="" src="https://static.wuzzuf-data.net/3411-1740310555633.0f5822c9acabd78ee904.js">
#   </script>
#   <script data-chunk="guest-jobseeker-landing-page-egypt" defer="" src="https://static.wuzzuf-data.net/7740-1740310555633.e2d742639873c3334ac3.js">
#   </script>
#   <script data-chunk="guest-jobseeker-landing-page-egypt" defer="" src="https://static.wuzzuf-data.net/5872-1740310555633.44ea7c77c34ddc25d542.js">
#   </script>
#   <script data-chunk="guest-jobseeker-landing-page-egypt" defer="" src="https://static.wuzzuf-data.net/4012-1740310555633.bb31f340e7c08f1b442e.js">
#   </script>
#   <script data-chunk="guest-jobseeker-landing-page-egypt" defer="" src="https://static.wuzzuf-data.net/guest-jobseeker-landing-page-egypt-1740310555633.0a38009bf49485c39ba3.js">
#   </script>
#   <script data-cf-beacon='{"token": "c0ca6af573dc4cd5973fdbdea3c92282"}' defer="" src="https://static.cloudflareinsights.com/beacon.min.js">
#   </script>
#  </body>
# </html>

# %%
html="<!DOCTYPE html><html><head><title>Page Title</title></head><body><h3><b id='boldest'>Lebron James</b></h3><p> Salary: $ 92,000,000 </p><h3> Stephen Curry</h3><p> Salary: $85,000, 000 </p><h3> Kevin Durant </h3><p> Salary: $73,200, 000</p></body></html>"
soup = BeautifulSoup(html, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Page Title
#   </title>
#  </head>
#  <body>
#   <h3>
#    <b id="boldest">
#     Lebron James
#    </b>
#   </h3>
#   <p>
#    Salary: $ 92,000,000
#   </p>
#   <h3>
#    Stephen Curry
#   </h3>
#   <p>
#    Salary: $85,000, 000
#   </p>
#   <h3>
#    Kevin Durant
#   </h3>
#   <p>
#    Salary: $73,200, 000
#   </p>
#  </body>
# </html>

# %%
print(soup.title)
print(soup.h3)
# Out:
# <title>Page Title</title>
# <h3><b id="boldest">Lebron James</b></h3>

# %%
t = soup.title
print(t)
print(t.parent)
print(t.children)
# Out:
# <title>Page Title</title>
# <head><title>Page Title</title></head>
# <list_iterator object at 0x000001B1BFC88A30>

# %%
h = soup.h3
print(h)
print("*"*50)
print(h.parent)
print("*"*50)
print(h.children)
print("*"*50)
print(h.nextSibling)
print("*"*50)
print(h.nextSibling.nextSibling)
# Out:
# <h3><b id="boldest">Lebron James</b></h3>
# **************************************************
# <body><h3><b id="boldest">Lebron James</b></h3><p> Salary: $ 92,000,000 </p><h3> Stephen Curry</h3><p> Salary: $85,000, 000 </p><h3> Kevin Durant </h3><p> Salary: $73,200, 000</p></body>
# **************************************************
# <list_iterator object at 0x000001B1C19FE3B0>
# **************************************************
# <p> Salary: $ 92,000,000 </p>
# **************************************************
# <h3> Stephen Curry</h3>

# %%
body = soup.body 
for child in body.children:
    print(child)
# Out:
# <h3><b id="boldest">Lebron James</b></h3>
# <p> Salary: $ 92,000,000 </p>
# <h3> Stephen Curry</h3>
# <p> Salary: $85,000, 000 </p>
# <h3> Kevin Durant </h3>
# <p> Salary: $73,200, 000</p>

# %%
print(soup.b)
tag = soup.b
print(tag.attrs)
# Out:
# <b id="boldest">Lebron James</b>
# {'id': 'boldest'}

# %%
tag.string
# Out:
# 'Lebron James'

# %%
table="<table><tr><td id='flight' >Flight No</td><td>Launch site</td><td>Payload mass</td></tr><tr><td>1</td><td><a href='https://en.wikipedia.org/wiki/Florida'>Florida</a></td><td>300 kg</td></tr><tr><td>2</td><td><a href='https://en.wikipedia.org/wiki/Texas'>Texas</a></td><td>94 kg</td></tr><tr><td>3</td><td><a href='https://en.wikipedia.org/wiki/Florida'>Florida</a> </td><td>80 kg</td></tr></table>"
soup = BeautifulSoup(table, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <table>
#  <tr>
#   <td id="flight">
#    Flight No
#   </td>
#   <td>
#    Launch site
#   </td>
#   <td>
#    Payload mass
#   </td>
#  </tr>
#  <tr>
#   <td>
#    1
#   </td>
#   <td>
#    <a href="https://en.wikipedia.org/wiki/Florida">
#     Florida
#    </a>
#   </td>
#   <td>
#    300 kg
#   </td>
#  </tr>
#  <tr>
#   <td>
#    2
#   </td>
#   <td>
#    <a href="https://en.wikipedia.org/wiki/Texas">
#     Texas
#    </a>
#   </td>
#   <td>
#    94 kg
#   </td>
#  </tr>
#  <tr>
#   <td>
#    3
#   </td>
#   <td>
#    <a href="https://en.wikipedia.org/wiki/Florida">
#     Florida
#    </a>
#   </td>
#   <td>
#    80 kg
#   </td>
#  </tr>
# </table>

# %%
print(soup.find_all("tr"))
# Out:
# [<tr><td id="flight">Flight No</td><td>Launch site</td><td>Payload mass</td></tr>, <tr><td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a></td><td>300 kg</td></tr>, <tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr>, <tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a> </td><td>80 kg</td></tr>]

# %%
rows = soup.find_all("tr")
print(rows[0])
print("*"*50)
for coulumn in rows[0]:
    print(coulumn)
# Out:
# <tr><td id="flight">Flight No</td><td>Launch site</td><td>Payload mass</td></tr>
# **************************************************
# <td id="flight">Flight No</td>
# <td>Launch site</td>
# <td>Payload mass</td>

# %%
print(soup.find_all(['tr', 'td']))
# Out:
# [<tr><td id="flight">Flight No</td><td>Launch site</td><td>Payload mass</td></tr>, <td id="flight">Flight No</td>, <td>Launch site</td>, <td>Payload mass</td>, <tr><td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a></td><td>300 kg</td></tr>, <td>1</td>, <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a></td>, <td>300 kg</td>, <tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr>, <td>2</td>, <td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td>, <td>94 kg</td>, <tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a> </td><td>80 kg</td></tr>, <td>3</td>, <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a> </td>, <td>80 kg</td>]

# %%
soup.find_all("td" , id="flight")
# Out:
# [<td id="flight">Flight No</td>]

# %%
soup.find_all(href=True)
# Out:
# [<a href="https://en.wikipedia.org/wiki/Florida">Florida</a>,
#  <a href="https://en.wikipedia.org/wiki/Texas">Texas</a>,
#  <a href="https://en.wikipedia.org/wiki/Florida">Florida</a>]
