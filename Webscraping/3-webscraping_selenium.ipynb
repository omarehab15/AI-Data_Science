# %% [markdown]
# # selenium

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\omar\miniconda3\lib\site-packages (4.27.1)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\omar\miniconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (2.2.3)
# Requirement already satisfied: trio~=0.17 in c:\users\omar\miniconda3\lib\site-packages (from selenium) (0.27.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\omar\miniconda3\lib\site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\omar\miniconda3\lib\site-packages (from selenium) (2024.8.30)
# Requirement already satisfied: typing_extensions~=4.9 in c:\users\omar\miniconda3\lib\site-packages (from selenium) (4.12.2)
# Requirement already satisfied: websocket-client~=1.8 in c:\users\omar\miniconda3\lib\site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\omar\miniconda3\lib\site-packages (from trio~=0.17->selenium) (24.3.0)
# Requirement already satisfied: sortedcontainers in c:\users\omar\miniconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\omar\miniconda3\lib\site-packages (from trio~=0.17->selenium) (3.7)
# Requirement already satisfied: outcome in c:\users\omar\miniconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\omar\miniconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: cffi>=1.14 in c:\users\omar\miniconda3\lib\site-packages (from trio~=0.17->selenium) (1.17.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\omar\miniconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\omar\miniconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\omar\miniconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\omar\miniconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
from selenium import webdriver

browser = webdriver.Chrome()
browser.get('http://google.com')  
print(browser.title)
browser.close()
# Out:
# Google

# %% [markdown]
# Find

# %%
from selenium.webdriver.common.by import By

browser = webdriver.Chrome()

browser.get('http://www.example.com/')
# print(browser.title)
data = browser.find_elements(By.TAG_NAME,'h1')
for e in data:
    print(e.text)
    print("*"*50)

browser.close()
# Out:
# Example Domain
# **************************************************

# %%
browser = webdriver.Chrome()

browser.get('http://www.example.com/')

data = browser.find_elements(By.TAG_NAME,"p")
for e in data:
    print("*"*50)
    print(e.text)
browser.close()
# Out:
# **************************************************
# This domain is for use in illustrative examples in documents. You may use this domain in literature without prior coordination or asking for permission.
# **************************************************
# More information...

# %%
browser = webdriver.Chrome()
browser.get('http://www.google.com')
# print(browser.title)

data = browser.find_elements(By.TAG_NAME,"div")
for e in data:
    print("*"*50)
    print(e.text)

browser.close()
# Out:
# **************************************************
# Gmailصور
# تسجيل الدخول
# محرّك بحث Google متوفّر باللغة: English
# مصر
# لمحة
# الإعلانات
# الأعمال
# آلية عمل "بحث Google"
# العقد الثالث من نشاطنا في مجال المناخ: تحقق من عملنا
# الخصوصية
# البنود
# الإعدادات
# **************************************************
# Gmailصور
# تسجيل الدخول
# **************************************************
# Gmailصور
# تسجيل الدخول
# **************************************************
# Gmailصور
# تسجيل الدخول
# **************************************************
# Gmailصور
# تسجيل الدخول
# **************************************************
# Gmailصور
# تسجيل الدخول
# **************************************************
# Gmailصور
# **************************************************
# Gmailصور
# **************************************************
# Gmail
# **************************************************
# صور
# **************************************************
# تسجيل الدخول
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
# محرّك بحث Google متوفّر باللغة: English
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
# محرّك بحث Google متوفّر باللغة: English
# **************************************************
# محرّك بحث Google متوفّر باللغة: English
# **************************************************
#
# **************************************************
# مصر
# لمحة
# الإعلانات
# الأعمال
# آلية عمل "بحث Google"
# العقد الثالث من نشاطنا في مجال المناخ: تحقق من عملنا
# الخصوصية
# البنود
# الإعدادات
# **************************************************
# مصر
# لمحة
# الإعلانات
# الأعمال
# آلية عمل "بحث Google"
# العقد الثالث من نشاطنا في مجال المناخ: تحقق من عملنا
# الخصوصية
# البنود
# الإعدادات
# **************************************************
# مصر
# **************************************************
# لمحة
# الإعلانات
# الأعمال
# آلية عمل "بحث Google"
# العقد الثالث من نشاطنا في مجال المناخ: تحقق من عملنا
# الخصوصية
# البنود
# الإعدادات
# **************************************************
# لمحة
# الإعلانات
# الأعمال
# آلية عمل "بحث Google"
# **************************************************
# العقد الثالث من نشاطنا في مجال المناخ: تحقق من عملنا
# **************************************************
# الخصوصية
# البنود
# الإعدادات
# **************************************************
# الإعدادات
# **************************************************
# الإعدادات
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************
#
# **************************************************

# %%
browser = webdriver.Chrome()
browser.get('https://www.amazon.eg/deals?ref_=nav_cs_gb')
# print(browser.title)

data = browser.find_elements(By.CLASS_NAME,"a-truncate-cut")
for e in data:
    print("*"*50)
    print(e.text)

browser.close()
# Out:
# **************************************************
# موبايل سمارت سامسونج جالاكسي A55 شبكة الجيل الخامس 5G، نظام أندرو…
# **************************************************
# تلفزيون سامسونج سمارت 65 بوصة 4 كيه الترا اتش دي ال اي - اسود - U…
# **************************************************
# تلفزيون ذكي ال جي ال اي دي 43 بوصة سلسلة LM6370 FHD HD…
# **************************************************
# كرتونة رمضان مكونة من 13 قطعة (2 كيس أرز + 2 كيس مكرونة + كيس…

# %%
browser = webdriver.Chrome()
browser.get('https://www.amazon.eg/-/en/%D9%85%D9%88%D8%A8%D8%A7%D9%8A%D9%84%D8%A7%D8%AA/b/?ie=UTF8&node=21832883031&ref_=nav_cs_mobiles')
# print(browser.title)

price = browser.find_elements(By.CLASS_NAME,"a-price-whole")
product = browser.find_elements(By.CLASS_NAME,"a-size-base-plus")
for pr,prod in zip (price,product):
    print("*"*50)
    print(prod.text)
    print(pr.text)

# browser.close()
# Out:
# **************************************************
# Samsung Galaxy A55 5G, Android Smartphone, Dual SIM Mobile Phone, 8GB RAM, 128GB Storage, Awesome Navy -1 Year Warranty/Local Version
# 19,999
# **************************************************
# Samsung Galaxy A16 LTE, Android Smartphone, Dual SIM Mobile Phone, 6GB RAM, 128GB Storage, Black (1 Year Local Warranty)
# 7,499
# **************************************************
# Xiaomi Redmi Note 14 Smartphone, 6 + 128 GB, Black, 108 MP AI Camera System, 5500 mAh Battery, 120 Hz Eye Protection Display, AI Functions | 18 Month manufacturer warranty
# 18,999
# **************************************************
# Infinix Hot 50 4G Smartphone, 256GB Storage, 8+8GB RAM (Titanium Grey)
# 4,554
# **************************************************
# Nokia 106 TA-1564 DS NENA1 Dual SIM 48MB Ram+128MB ROM (1.8 Inches) (2G) - (Charcoal)
#
# **************************************************
# Redmi 13 Mobile, Midnight Black (6GB Ram+128GB) |Mediatek helio G91 ultra processor| 6.79" FHD+ 90Hz display | Triple Camera 108MP + 2MP, 13MP Front camera |2-pin charger |1 year manufacturer warranty
#
# **************************************************
# Samsung Galaxy M55 5G, Android Smartphone, Dual SIM Mobile Phone, 8GB RAM, 256GB Storage, Black 1 Year Warranty/Local Version
#
# **************************************************
# Xiaomi Redmi Note 13 Dual SIM Smartphone 6GB RAM | 128GB ROM, 6.67- Inches (4G) (Mint Green) |1 year manufacturer warranty
#
# **************************************************
# Infinix Hot 50i 6+6GB RAM 128GB Smartphone, Sage Green
# 8,888
# **************************************************
# Redmi Xiaomi 12 8GB RAM, 128GB ROM 90Hz 6.79” FHD+ display Large 5000mAh (typ) battery 50MP Al triple camera IP53 dust and splash resistant Large 90Hz FHD 1 year local warranty, Midnight Black
# 8,888
# **************************************************
# Infinix Smart 9 (RAM: 4+4GB, ROM: 128GB), 6.7 inch HD+Screen, 13MP AI Dual Back Camera, 8MP Front Camera, 5000mAh Battery, Dual Nano SIM, Type-C, Android 14 - Green
# 8,888
# **************************************************
# Samsung Galaxy A06 Dual Sim 6GB RAM 128GB Storage Android Smartphone, 6.7-Inch Screen Size, Black- 1 Year Warranty/Local Version
# 9,999

# %%
# Locating by XPATH
browser = webdriver.Chrome()
browser.get('https://www.amazon.eg/-/en/%D8%A5%D9%84%D9%83%D8%AA%D8%B1%D9%88%D9%86%D9%8A%D8%A7%D8%AA/b/?ie=UTF8&node=18018102031&ref_=nav_cs_electronics')
price = browser.find_elements(By.XPATH,"//span[@class='a-price-whole']")
product = browser.find_elements(By.XPATH,"//a/h2/span")
print(price)
# print(product)
for pr,prod in zip(price,product):
# for prod in product:
    print("*"*50)
    # print(prod.text)
    print(prod.text)
    print(pr.text)
# for pr in price:
#     print("*****")
#     # print(prod.text)
#     print(pr.text)
browser.close()
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="626beedfdc339c4be462300fd68a96d2", element="f.F11A2BF06B5234A70122F60BA859F2A1.d.56F01F266036859F4EDFF167C1045991.e.52")>, <selenium.webdriver.remote.webelement.WebElement (session="626beedfdc339c4be462300fd68a96d2", element="f.F11A2BF06B5234A70122F60BA859F2A1.d.56F01F266036859F4EDFF167C1045991.e.53")>, <selenium.webdriver.remote.webelement.WebElement (session="626beedfdc339c4be462300fd68a96d2", element="f.F11A2BF06B5234A70122F60BA859F2A1.d.56F01F266036859F4EDFF167C1045991.e.54")>, <selenium.webdriver.remote.webelement.WebElement (session="626beedfdc339c4be462300fd68a96d2", element="f.F11A2BF06B5234A70122F60BA859F2A1.d.56F01F266036859F4EDFF167C1045991.e.55")>, <selenium.webdriver.remote.webelement.WebElement (session="626beedfdc339c4be462300fd68a96d2", element="f.F11A2BF06B5234A70122F60BA859F2A1.d.56F01F266036859F4EDFF167C1045991.e.56")>, <selenium.webdriver.remote.webelement.WebElement (session="626beedfdc339c4be462300fd68a96d2", element="f.F11A2BF06B5234A70122F60BA859F2A1.d.56F01F266036859F4EDFF167C1045991.e.57")>, <selenium.webdriver.remote.webelement.WebElement (session="626beedfdc339c4be462300fd68a96d2", element="f.F11A2BF06B5234A70122F60BA859F2A1.d.56F01F266036859F4EDFF167C1045991.e.58")>, <selenium.webdriver.remote.webelement.WebElement (session="626beedfdc339c4be462300fd68a96d2", element="f.F11A2BF06B5234A70122F60BA859F2A1.d.56F01F266036859F4EDFF167C1045991.e.59")>, <selenium.webdriver.remote.webelement.WebElement (session="626beedfdc339c4be462300fd68a96d2", element="f.F11A2BF06B5234A70122F60BA859F2A1.d.56F01F266036859F4EDFF167C1045991.e.60")>, <selenium.webdriver.remote.webelement.WebElement (session="626beedfdc339c4be462300fd68a96d2", element="f.F11A2BF06B5234A70122F60BA859F2A1.d.56F01F266036859F4EDFF167C1045991.e.61")>, <selenium.webdriver.remote.webelement.WebElement (session="626beedfdc339c4be462300fd68a96d2", element="f.F11A2BF06B5234A70122F60BA859F2A1.d.56F01F266036859F4EDFF167C1045991.e.62")>, <selenium.webdriver.remote.webelement.WebElement (session="626beedfdc339c4be462300fd68a96d2", element="f.F11A2BF06B5234A70122F60BA859F2A1.d.56F01F266036859F4EDFF167C1045991.e.63")>, <selenium.webdriver.remote.webelement.WebElement (session="626beedfdc339c4be462300fd68a96d2", element="f.F11A2BF06B5234A70122F60BA859F2A1.d.56F01F266036859F4EDFF167C1045991.e.64")>, <selenium.webdriver.remote.webelement.WebElement (session="626beedfdc339c4be462300fd68a96d2", element="f.F11A2BF06B5234A70122F60BA859F2A1.d.56F01F266036859F4EDFF167C1045991.e.65")>, <selenium.webdriver.remote.webelement.WebElement (session="626beedfdc339c4be462300fd68a96d2", element="f.F11A2BF06B5234A70122F60BA859F2A1.d.56F01F266036859F4EDFF167C1045991.e.66")>, <selenium.webdriver.remote.webelement.WebElement (session="626beedfdc339c4be462300fd68a96d2", element="f.F11A2BF06B5234A70122F60BA859F2A1.d.56F01F266036859F4EDFF167C1045991.e.67")>, <selenium.webdriver.remote.webelement.WebElement (session="626beedfdc339c4be462300fd68a96d2", element="f.F11A2BF06B5234A70122F60BA859F2A1.d.56F01F266036859F4EDFF167C1045991.e.68")>, <selenium.webdriver.remote.webelement.WebElement (session="626beedfdc339c4be462300fd68a96d2", element="f.F11A2BF06B5234A70122F60BA859F2A1.d.56F01F266036859F4EDFF167C1045991.e.69")>, <selenium.webdriver.remote.webelement.WebElement (session="626beedfdc339c4be462300fd68a96d2", element="f.F11A2BF06B5234A70122F60BA859F2A1.d.56F01F266036859F4EDFF167C1045991.e.70")>, <selenium.webdriver.remote.webelement.WebElement (session="626beedfdc339c4be462300fd68a96d2", element="f.F11A2BF06B5234A70122F60BA859F2A1.d.56F01F266036859F4EDFF167C1045991.e.71")>, <selenium.webdriver.remote.webelement.WebElement (session="626beedfdc339c4be462300fd68a96d2", element="f.F11A2BF06B5234A70122F60BA859F2A1.d.56F01F266036859F4EDFF167C1045991.e.72")>, <selenium.webdriver.remote.webelement.WebElement (session="626beedfdc339c4be462300fd68a96d2", element="f.F11A2BF06B5234A70122F60BA859F2A1.d.56F01F266036859F4EDFF167C1045991.e.73 ...
# **************************************************
# Samsung 55 Inch QLED Smart TV Neural HDR Quantum Processor Lite 4K - QA55QE1DAUXEG [2024 Model]
# 18,499
# **************************************************
# LG LED Smart TV 43 inch LM6370 Series Full HD HDR Smart LED TV - 43LM6370PVA
# 19,999
# **************************************************
# Oraimo FreePods 3C ENC Calling Noise Cancellation, powerful bass 4 mics, Long Playtime True Wireless Earbuds IPX5-Water Resistant, Via App Black
# 12,199
# **************************************************
# Oraimo FreePods Lite True Wireless Earbuds Bluetooth TWS Earphone with APP Control,40h Play Time, Anifast Fast Charging,in-Ear Earbuds with Stereo Bass,Black
# 15,699
# **************************************************
# Anker Soundcore By Anker R50i True Wireless Earbuds 10mm Drivers with Big Bass, Bluetooth 5.3, 30H Playtime, IPX5-Water Resistant, AI Clear Calls with 2 Mics, 22 Preset EQs via App, 18 Months Warranty
#
# **************************************************
# Samsung 32 Inch Full HD Smart LED TV with Built-in Receiver - Black - UA32T5300AUXEG
#
# **************************************************
# Samsung Galaxy A55 5G, Android Smartphone, Dual SIM Mobile Phone, 8GB RAM, 128GB Storage, Awesome Navy -1 Year Warranty/Local Version
#
# **************************************************
# Samsung 50 Inch 4K UHD Smart LED TV - Black - UA50DU7000UXEG [2024 Model]
#
# **************************************************
# JAC 43 Inch FHD Smart LED TV NGLD, Black - 43JC6121B
# 2,588
# **************************************************
# LG UHD 4K TV 60 Inch UQ7900 Series, Cinema Screen Design 4K Active HDR WebOS Smart AI ThinQ - 60UQ79006LD (New)
# 2,750
# **************************************************
# Anker Soundcore R50i Black True Wireless (TWS) Earbuds 10mm Drivers with Big Bass, Bluetooth 5.3, 30H Playtime, IPX5-Water Resistant, AI Clear Calls with 2 Mics, 22 Preset EQs via App
# 2,635
# **************************************************
# LG 65 Inch UHD UT80 4K Smart TV AI Magic remote HDR10 webOS24-65UT80006LB (2024)
# 3,595

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

browser = webdriver.Chrome()
browser.get('https://www.google.com/')
search_bar = browser.find_element(By.TAG_NAME,'textarea')
search_bar.send_keys('Python',Keys.ENTER)
time.sleep(5)
browser.close()

# %%
browser = webdriver.Chrome()
browser.get('https://www.google.com/')
search_bar = browser.find_element(By.TAG_NAME,'textarea')
search_bar.send_keys('Python',Keys.ENTER)
time.sleep(5)

links = browser.find_elements(By.XPATH,'//h3')
for link in links:
    print(link.text)

browser.close()

# %%
browser = webdriver.Chrome()

browser.get('https://www.google.com/')
search_bar = browser.find_element(By.TAG_NAME,"textarea")
search_bar.send_keys("Amazon eg",Keys.ENTER)
browser.implicitly_wait(5)
links = browser.find_elements(By.XPATH,"//span[@dir='ltr']")
for link in links:
    print(link.text)
next = browser.find_element(By.XPATH, "//span[@class='oeN89d']/span[@dir='rtl']")
# if next:
#     next.click()
# browser.close()

data = pd.DataFrame({"Link":[link.text for link in links]})
print(data.head())
data.to_csv("amazon_links.csv")
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[27], line 10
#       8 for link in links:
#       9     print(link.text)
# ---> 10 next = browser.find_element(By.XPATH, "//span[@class='oeN89d']/span[@dir='rtl']")
#      11 # if next:
#      12 #     next.click()
#      13 # browser.close()
#      15 data = pd.DataFrame({"Link":[link.text for link in links]})
#
# File c:\Users\omar\miniconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:770, in WebDriver.find_element(self, by, value)
#     767         raise NoSuchElementException(f"Cannot locate relative element with: {by.root}")
#     768     return elements[0]
# --> 770 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\omar\miniconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:384, in WebDriver.execute(self, driver_command, params)
#     382 response = self.command_executor.execute(driver_command, params)
#     383 if response:
# --> 384     self.error_handler.check_response(response)
#     385     response["value"] = self._unwrap_value(response.get("value", None))
#     386     return response
#
# File c:\Users\omar\miniconda3\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 232 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//span[@class='oeN89d']/span[@dir='rtl']"}
#   (Session info: chrome=133.0.6943.141); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF6C6CAC6A5+28789]
# 	(No symbol) [0x00007FF6C6C15B20]
# 	(No symbol) [0x00007FF6C6AA8F9A]
# 	(No symbol) [0x00007FF6C6AFF346]
# 	(No symbol) [0x00007FF6C6AFF57C]
# 	(No symbol) [0x00007FF6C6B52B17]
# 	(No symbol) [0x00007FF6C6B2736F]
# 	(No symbol) [0x00007FF6C6B4F7E3]
# 	(No symbol) [0x00007FF6C6B27103]
# 	(No symbol) [0x00007FF6C6AEFFC0]
# 	(No symbol) [0x00007FF6C6AF1273]
# 	GetHandleVerifier [0x00007FF6C6FF1AED+3458237]
# 	GetHandleVerifier [0x00007FF6C700829C+3550316]
# 	GetHandleVerifier [0x00007FF6C6FFDB9D+3507565]
# 	GetHandleVerifier [0x00007FF6C6D72C6A+841274]
# 	(No symbol) [0x00007FF6C6C209EF]
# 	(No symbol) [0x00007FF6C6C1CB34]
# 	(No symbol) [0x00007FF6C6C1CCD6]
# 	(No symbol) [0x00007FF6C6C0C119]
# 	BaseThreadInitThunk [0x00007FFA3E41E8D7+23]
# 	RtlUserThreadStart [0x00007FFA3FF150AC+44]

# %%
browser = webdriver.Chrome()
browser.get("https://www.google.com")
search_bar = browser.find_element(By.CLASS_NAME,"gLFyf")
search_bar.send_keys("Python",Keys.ENTER)
# browser.implicitly_wait(5)
time.sleep(3)

headers = browser.find_elements(By.XPATH, "//h3")
for h in headers:
    print(h.text)

next_page = browser.find_element(By.XPATH,"//span[@class='oeN89d']")
while True:
    if next_page:
        next_page.click()
        time.sleep(3)
        headers = browser.find_elements(By.XPATH, "//h3")
        for h in headers:
            print(h.text)
    else:
        break

    next_page = browser.find_elements(By.XPATH,"//span[@class='oeN89d']")[-1]

browser.close()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[29], line 12
#       9 for h in headers:
#      10     print(h.text)
# ---> 12 next_page = browser.find_element(By.XPATH,"//span[@class='oeN89d']")
#      13 while True:
#      14     if next_page:
#
# File c:\Users\omar\miniconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:770, in WebDriver.find_element(self, by, value)
#     767         raise NoSuchElementException(f"Cannot locate relative element with: {by.root}")
#     768     return elements[0]
# --> 770 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\omar\miniconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:384, in WebDriver.execute(self, driver_command, params)
#     382 response = self.command_executor.execute(driver_command, params)
#     383 if response:
# --> 384     self.error_handler.check_response(response)
#     385     response["value"] = self._unwrap_value(response.get("value", None))
#     386     return response
#
# File c:\Users\omar\miniconda3\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 232 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//span[@class='oeN89d']"}
#   (Session info: chrome=133.0.6943.141); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF6C6CAC6A5+28789]
# 	(No symbol) [0x00007FF6C6C15B20]
# 	(No symbol) [0x00007FF6C6AA8F9A]
# 	(No symbol) [0x00007FF6C6AFF346]
# 	(No symbol) [0x00007FF6C6AFF57C]
# 	(No symbol) [0x00007FF6C6B52B17]
# 	(No symbol) [0x00007FF6C6B2736F]
# 	(No symbol) [0x00007FF6C6B4F7E3]
# 	(No symbol) [0x00007FF6C6B27103]
# 	(No symbol) [0x00007FF6C6AEFFC0]
# 	(No symbol) [0x00007FF6C6AF1273]
# 	GetHandleVerifier [0x00007FF6C6FF1AED+3458237]
# 	GetHandleVerifier [0x00007FF6C700829C+3550316]
# 	GetHandleVerifier [0x00007FF6C6FFDB9D+3507565]
# 	GetHandleVerifier [0x00007FF6C6D72C6A+841274]
# 	(No symbol) [0x00007FF6C6C209EF]
# 	(No symbol) [0x00007FF6C6C1CB34]
# 	(No symbol) [0x00007FF6C6C1CCD6]
# 	(No symbol) [0x00007FF6C6C0C119]
# 	BaseThreadInitThunk [0x00007FFA3E41E8D7+23]
# 	RtlUserThreadStart [0x00007FFA3FF150AC+44]

# %%
browser = webdriver.Chrome()
browser.get("https://www.google.com")
search_bar = browser.find_element(By.CLASS_NAME,"gLFyf")
search_bar.send_keys("Python",Keys.ENTER)
# browser.implicitly_wait(5)
time.sleep(3)
images_button = browser.find_elements(By.XPATH,"/html/body/div[3]/div/div[3]/div/div/div/div/div/div/div[1]/div/div[2]/a")[0]
# print(images_button)
images_button.click()
time.sleep(1)
images = browser.find_elements(By.XPATH,"//div/g-img/img")

for img in images:
    print(img.get_attribute("src"))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[31], line 7
#       5 # browser.implicitly_wait(5)
#       6 time.sleep(3)
# ----> 7 images_button = browser.find_elements(By.XPATH,"/html/body/div[3]/div/div[3]/div/div/div/div/div/div/div[1]/div/div[2]/a")[0]
#       8 # print(images_button)
#       9 images_button.click()
#
# IndexError: list index out of range

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import requests
import os

def download_images(search_query, num_images):
    # Set up the Chrome WebDriver
    options = webdriver.ChromeOptions()
    # options.add_argument('--headless')  # Run in headless mode (no GUI)
    driver = webdriver.Chrome(options=options)

    # Create a directory to save images
    if not os.path.exists(search_query):
        os.makedirs(search_query)

    # Construct the search URL and navigate to it
    search_url = f"https://www.google.com/search?hl=en&tbm=isch&q={search_query}"
    driver.get(search_url)

    # Wait for images to load
    time.sleep(2)

    # Find image elements on the page
    image_elements = driver.find_elements(By.CLASS_NAME, 'rg_i')
    print(image_elements)
    count = 0
    for img in image_elements:
        try:
            img.click()  # Click on the thumbnail to open the full image
            time.sleep(1)  # Wait for the full image to load
            
            # Locate the full-size image element and get its URL
            full_img_element = driver.find_element(By.CLASS_NAME, 'n3VNCb')
            img_url = full_img_element.get_attribute("src")

            # Download the image if it's a valid URL
            if img_url.startswith('http'):
                response = requests.get(img_url)
                if response.status_code == 200:
                    with open(os.path.join(search_query, f'image_{count + 1}.jpg'), 'wb') as file:
                        file.write(response.content)
                        count += 1

            # Stop after downloading the specified number of images
            if count >= num_images:
                break

        except Exception as e:
            print(f"An error occurred: {e}")

    driver.quit()  # Close the browser

# Example usage: Download 5 images of "cats"
download_images("cats", 5)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[32], line 55
#      52     driver.quit()  # Close the browser
#      54 # Example usage: Download 5 images of "cats"
# ---> 55 download_images("cats", 5)
#
# Cell In[32], line 15, in download_images(search_query, num_images)
#      13 # Create a directory to save images
#      14 if not os.path.exists(search_query):
# ---> 15     os.makedirs(search_query)
#      17 # Construct the search URL and navigate to it
#      18 search_url = f"https://www.google.com/search?hl=en&tbm=isch&q={search_query}"
#
# File <frozen os>:225, in makedirs(name, mode, exist_ok)
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'cats'

# %%
driver = webdriver.Chrome()
driver.get("https:example.com")
data = driver.find_element(By.XPATH,"//div/p[1]")
print(data.text)
# Out:
# This domain is for use in illustrative examples in documents. You may use this domain in literature without prior coordination or asking for permission.
