# %%
# !pip install pywaffle
# Out:
# Requirement already satisfied: pywaffle in c:\users\omar\miniconda3\lib\site-packages (1.1.1)
# Requirement already satisfied: fontawesomefree in c:\users\omar\miniconda3\lib\site-packages (from pywaffle) (6.6.0)
# Requirement already satisfied: matplotlib in c:\users\omar\miniconda3\lib\site-packages (from pywaffle) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\omar\miniconda3\lib\site-packages (from matplotlib->pywaffle) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\omar\miniconda3\lib\site-packages (from matplotlib->pywaffle) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\omar\miniconda3\lib\site-packages (from matplotlib->pywaffle) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\omar\miniconda3\lib\site-packages (from matplotlib->pywaffle) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\omar\miniconda3\lib\site-packages (from matplotlib->pywaffle) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\omar\miniconda3\lib\site-packages (from matplotlib->pywaffle) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\omar\miniconda3\lib\site-packages (from matplotlib->pywaffle) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\omar\miniconda3\lib\site-packages (from matplotlib->pywaffle) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\omar\miniconda3\lib\site-packages (from matplotlib->pywaffle) (2.9.0)
# Requirement already satisfied: six>=1.5 in c:\users\omar\miniconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->pywaffle) (1.16.0)

# %%
# Create a Waffle chart
import matplotlib.pyplot as plt
from pywaffle import Waffle

data = {'Democratic': 48, 'Republican': 46, 'Libertarian': 3}
fig = plt.figure(
    FigureClass=Waffle, 
    rows=3,
    columns=10,
    values=data,
    # colors=("#983D3D", "#232066", "#DCB732"),
    legend={'loc': 'upper left', 'bbox_to_anchor': (1, 1)}
)
plt.show()
# Out:
# <Waffle size 640x480 with 1 Axes>

# %%
# Create a pie chart 
fig , ax = plt.subplots()
ax.pie(data.values(), labels=data.keys(), autopct='%1.1f%%', startangle=90)
ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
import pandas as pd
data = pd.read_csv('data\\twitter_validation.csv', header=None)
data.head()
# Out:
#       0          1           2  \
# 0  3364   Facebook  Irrelevant
# 1   352     Amazon     Neutral
# 2  8312  Microsoft    Negative
# 3  4371      CS-GO    Negative
# 4  4433     Google     Neutral
#
#                                                    3
# 0  I mentioned on Facebook that I was struggling ...
# 1  BBC News - Amazon boss Jeff Bezos rejects clai...
# 2  @Microsoft Why do I pay for WORD when it funct...
# 3  CSGO matchmaking is so full of closet hacking,...
# 4  Now the President is slapping Americans in the...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       1000 non-null   int64
#  1   1       1000 non-null   object
#  2   2       1000 non-null   object
#  3   3       1000 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 31.4+ KB

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\omar\miniconda3\lib\site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\omar\miniconda3\lib\site-packages (from wordcloud) (2.1.3)
# Requirement already satisfied: pillow in c:\users\omar\miniconda3\lib\site-packages (from wordcloud) (11.1.0)
# Requirement already satisfied: matplotlib in c:\users\omar\miniconda3\lib\site-packages (from wordcloud) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\omar\miniconda3\lib\site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\omar\miniconda3\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\omar\miniconda3\lib\site-packages (from matplotlib->wordcloud) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\omar\miniconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\omar\miniconda3\lib\site-packages (from matplotlib->wordcloud) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\omar\miniconda3\lib\site-packages (from matplotlib->wordcloud) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\omar\miniconda3\lib\site-packages (from matplotlib->wordcloud) (2.9.0)
# Requirement already satisfied: six>=1.5 in c:\users\omar\miniconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text= ' '.join(data[3])
# background_color= 'white'
wordcloud = WordCloud().generate(text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
text.count('team')
# Out:
# 34

# %%
txt = '''World War II[b] or the Second World War (1 September 1939 – 2 September 1945) was a global conflict between two coalitions: the Allies and the Axis powers. Nearly all of the world's countries participated, with many nations mobilising all resources in pursuit of total war. Tanks and aircraft played major roles, enabling the strategic bombing of cities and delivery of the first and only nuclear weapons ever used in war. World War II was the deadliest conflict in history, resulting in 70 to 85 million deaths, more than half of which were civilians. Millions died in genocides, including the Holocaust, and by massacres, starvation, and disease. After the Allied victory, Germany, Austria, Japan, and Korea were occupied, and German and Japanese leaders were tried for war crimes.

The causes of World War II included unresolved tensions in the aftermath of World War I and the rises of fascism in Europe and militarism in Japan. Key events preceding the war included Japan's invasion of Manchuria in 1931, the Spanish Civil War, the outbreak of the Second Sino-Japanese War in 1937, and Germany's annexations of Austria and the Sudetenland. World War II is generally considered to have begun on 1 September 1939, when Nazi Germany, under Adolf Hitler, invaded Poland, leading the United Kingdom and France to declare war on Germany. Poland was divided between Germany and the Soviet Union under the Molotov–Ribbentrop Pact. In 1940, the Soviets annexed the Baltic states and parts of Finland and Romania. After the fall of France in June 1940, the war continued mainly between Germany and the British Empire, with fighting in the Balkans, Mediterranean, and Middle East, the aerial Battle of Britain and the Blitz, and naval Battle of the Atlantic. Through campaigns and treaties, Germany gained control of much of continental Europe and formed the Axis alliance with Italy, Japan, and other countries. In June 1941, Germany led an invasion of the Soviet Union, opening the Eastern Front and initially making large territorial gains.
'''
wordcloud = WordCloud().generate(txt)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\omar\miniconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\omar\miniconda3\lib\site-packages (from seaborn) (2.1.3)
# Requirement already satisfied: pandas>=1.2 in c:\users\omar\miniconda3\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\omar\miniconda3\lib\site-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\omar\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\omar\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\omar\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\omar\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\omar\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\omar\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\omar\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\omar\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\omar\miniconda3\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\omar\miniconda3\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\omar\miniconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %%
import seaborn as sns
import pandas as pd
data = pd.read_csv('data\\housing.csv', header=None, sep= '\s+')
data.columns = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
data.head()
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\omar\AppData\Local\Temp\ipykernel_4352\579765198.py:3: SyntaxWarning: invalid escape sequence '\s'
#   data = pd.read_csv('data\\housing.csv', header=None, sep= '\s+')
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
#plot regression line 
sns.regplot(x='RM', y='MEDV', data=data)
plt.show()

# %%
#plot regression line 
sns.regplot(x='CRIM', y='MEDV', data=data)
plt.show()

# %%
data = {'Democratic': 48, 'Republican': 46, 'Libertarian': 3}
sns.barplot(x=list(data.keys()), y=list(data.values()))
plt.show()

# %%
import pandas as pd
data = pd.read_csv('data\\twitter_validation.csv', header=None)
print(data.head())
print(data[2].value_counts())
sns.countplot(x=data[2])
plt.show()
# Out:
#       0          1           2  \
# 0  3364   Facebook  Irrelevant
# 1   352     Amazon     Neutral
# 2  8312  Microsoft    Negative
# 3  4371      CS-GO    Negative
# 4  4433     Google     Neutral
#
#                                                    3
# 0  I mentioned on Facebook that I was struggling ...
# 1  BBC News - Amazon boss Jeff Bezos rejects clai...
# 2  @Microsoft Why do I pay for WORD when it funct...
# 3  CSGO matchmaking is so full of closet hacking,...
# 4  Now the President is slapping Americans in the...
# 2
# Neutral       285
# Positive      277
# Negative      266
# Irrelevant    172
# Name: count, dtype: int64

# %%
# !pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.19.5-py2.py3-none-any.whl.metadata (4.1 kB)
# Collecting branca>=0.6.0 (from folium)
#   Downloading branca-0.8.1-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jinja2>=2.9 in c:\users\omar\miniconda3\lib\site-packages (from folium) (3.1.5)
# Requirement already satisfied: numpy in c:\users\omar\miniconda3\lib\site-packages (from folium) (2.1.3)
# Requirement already satisfied: requests in c:\users\omar\miniconda3\lib\site-packages (from folium) (2.32.3)
# Collecting xyzservices (from folium)
#   Downloading xyzservices-2025.1.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\omar\miniconda3\lib\site-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\omar\miniconda3\lib\site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\omar\miniconda3\lib\site-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\omar\miniconda3\lib\site-packages (from requests->folium) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\omar\miniconda3\lib\site-packages (from requests->folium) (2024.8.30)
# Downloading folium-0.19.5-py2.py3-none-any.whl (110 kB)
# Downloading branca-0.8.1-py3-none-any.whl (26 kB)
# Downloading xyzservices-2025.1.0-py3-none-any.whl (88 kB)
# Installing collected packages: xyzservices, branca, folium
# Successfully installed branca-0.8.1 folium-0.19.5 xyzservices-2025.1.0

# %%
import folium
map = folium.Map()
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_83f876f86cc1d3f589c9426b5921b2a8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_83f876f86cc1d3f589c9426b5921b2a8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_83f876f86cc1d3f589c9426b5921b2a8 = L.map(
#                 &quot;map_83f876f86cc1d3f589c9426b5921b2a8&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_61753d028e6bf66d3fd1edc9b0db63f3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_61753d028e6bf66d3fd1edc9b0db63f3.addTo(map_83f876f86cc1d3f589c9426b5921b2a8);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# create a map for canada
map = folium.Map(location=[56.130, -106.35], zoom_start=4)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_41c282f83fc795ccd34120417e363eb7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_41c282f83fc795ccd34120417e363eb7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_41c282f83fc795ccd34120417e363eb7 = L.map(
#                 &quot;map_41c282f83fc795ccd34120417e363eb7&quot;,
#                 {
#                     center: [56.13, -106.35],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1f99b97348d7ddcbd4a14d6f76945d71 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1f99b97348d7ddcbd4a14d6f76945d71.addTo(map_41c282f83fc795ccd34120417e363eb7);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
canada_map = folium.Map(location=[56.130, -106.35],
                 zoom_start=4,
                 tiles='https://tileserver.memomaps.de/tilegen/{z}/{x}/{y}.png',
                 attr= 'Map <a href="https://memomaps.de/">memomaps.de</a> <a href="http://creativecommons.org/licenses/by-sa/2.0/">CC-BY-SA</a>, map data &copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors'
)
canada_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4ef3aa6c79105a09396e61c91b018bc8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4ef3aa6c79105a09396e61c91b018bc8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4ef3aa6c79105a09396e61c91b018bc8 = L.map(
#                 &quot;map_4ef3aa6c79105a09396e61c91b018bc8&quot;,
#                 {
#                     center: [56.13, -106.35],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eeae6f4646101a1f5325c86fb63ad049 = L.tileLayer(
#                 &quot;https://tileserver.memomaps.de/tilegen/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Map \u003ca href=\&quot;https://memomaps.de/\&quot;\u003ememomaps.de\u003c/a\u003e \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/2.0/\&quot;\u003eCC-BY-SA\u003c/a\u003e, map data \u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_eeae6f4646101a1f5325c86fb63ad049.addTo(map_4ef3aa6c79105a09396e61c91b018bc8);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# add marker 
import folium.features


folium.Marker([45.3288, -119.6625], popup='<i>Mt. Hood Meadows</i>').add_to(canada_map)
folium.CircleMarker([45.3288, -121.6625], radius=50, color='red', fill=True, fill_color='red').add_to(canada_map)
folium.Marker([45.3311, -121.7113], popup='<b>Timberline Lodge</b>').add_to(canada_map)
folium.Marker([45.3300, -121.6823], popup='<b>Some Other Location</b>').add_to(canada_map)
canada_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4ef3aa6c79105a09396e61c91b018bc8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4ef3aa6c79105a09396e61c91b018bc8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4ef3aa6c79105a09396e61c91b018bc8 = L.map(
#                 &quot;map_4ef3aa6c79105a09396e61c91b018bc8&quot;,
#                 {
#                     center: [56.13, -106.35],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eeae6f4646101a1f5325c86fb63ad049 = L.tileLayer(
#                 &quot;https://tileserver.memomaps.de/tilegen/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Map \u003ca href=\&quot;https://memomaps.de/\&quot;\u003ememomaps.de\u003c/a\u003e \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/2.0/\&quot;\u003eCC-BY-SA\u003c/a\u003e, map data \u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_eeae6f4646101a1f5325c86fb63ad049.addTo(map_4ef3aa6c79105a09396e61c91b018bc8);
#
#
#             tile_layer_eeae6f4646101a1f5325c86fb63ad049.addTo(map_4ef3aa6c79105a09396e61c91b018bc8);
#
#
#             var marker_f149c57cabc5f755c820ff52e6f02a9e = L.marker(
#                 [45.3288, -119.6625],
#                 {
# }
#             ).addTo(map_4ef3aa6c79105a09396e61c91b018bc8);
#
#
#         var popup_d06cd7e60d54ce5c547c8395459d3268 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_34cd88b2f2d8f4f6578382a0cd656f2e = $(`&lt;div id=&quot;html_34cd88b2f2d8f4f6578382a0cd656f2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;Mt. Hood Meadows&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_d06cd7e60d54ce5c547c8395459d3268.setContent(html_34cd88b2f2d8f4f6578382a0cd656f2e);
#
#
#
#         marker_f149c57cabc5f755c820ff52e6f02a9e.bindPopup(popup_d06cd7e60d54ce5c547c8395459d3268)
#         ;
#
#
#
#
#             var circle_marker_04008d0d0bfd9844fe6a2293965f1f7d = L.circleMarker(
#                 [45.3288, -121.6625],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4ef3aa6c79105a09396e61c91b018bc8);
#
#
#             var marker_c5991624c90ea0dd68793d6e1a1299d9 = L.marker(
#                 [45.3311, -121.7113],
#                 {
# }
#             ).addTo(map_4ef3aa6c79105a09396e61c91b018bc8);
#
#
#         var popup_9f5918e786d0a3c76b3f2e0d5e81a5c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_64a675c1724308843dc6fd4fd2462b70 = $(`&lt;div id=&quot;html_64a675c1724308843dc6fd4fd2462b70&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Timberline Lodge&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_9f5918e786d0a3c76b3f2e0d5e81a5c9.setContent(html_64a675c1724308843dc6fd4fd2462b70);
#
#
#
#         marker_c5991624c90ea0dd68793d6e1a1299d9.bindPopup(popup_9f5918e786d0a3c76b3f2e0d5e81a5c9)
#         ;
#
#
#
#
#             var marker_b3ea8c19af8c888717af0bc4bd3966bd = L.marker(
#                 [45.33, -121.6823],
#                 {
# }
#             ).addTo(map_4ef3aa6c79105a09396e61c91b018bc8);
#
#
#         var popup_fada21f07219d6d9daf22712b0079d51 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b48dbf9dc552b0b602e50d73bb1e42a = $(`&lt;div id=&quot;html_6b48dbf9dc552b0b602e50d73bb1e42a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Some Other Location&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_fada21f07219d6d9daf22712b0079d51.setContent(html_6b48dbf9dc552b0b602e50d73bb1e42a);
#
#
#
#         marker_b3ea8c19af8c888717af0bc4bd3966bd.bindPopup(popup_fada21f07219d6d9daf22712b0079d51)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Creaet a choropleth map
import pandas as pd
import folium
import json

data = pd.read_csv('data\\InfantMortalityRate.csv', encoding='latin1')
data.head()
# Out:
#                 Country  Infant Mortality Rate  Gender    Year
# 0           Afghanistan              43.050731  Female  2019.0
# 1                Angola              44.851045  Female  2019.0
# 2               Albania               7.659442  Female  2019.0
# 3               Andorra               2.555451  Female  2019.0
# 4  United Arab Emirates               5.716825  Female  2019.0

# %%
data_2019 = data[data['Year'] == 2019]
data_2019.head()
# Out:
#                 Country  Infant Mortality Rate  Gender    Year
# 0           Afghanistan              43.050731  Female  2019.0
# 1                Angola              44.851045  Female  2019.0
# 2               Albania               7.659442  Female  2019.0
# 3               Andorra               2.555451  Female  2019.0
# 4  United Arab Emirates               5.716825  Female  2019.0

# %%
data_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 693 entries, 0 to 5312
# Data columns (total 4 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                693 non-null    object
#  1   Infant Mortality Rate  693 non-null    float64
#  2   Gender                 693 non-null    object
#  3   Year                   693 non-null    float64
# dtypes: float64(2), object(2)
# memory usage: 27.1+ KB

# %%
# !pip install geopy
# Out:
# Collecting geopy
#   Downloading geopy-2.4.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting geographiclib<3,>=1.52 (from geopy)
#   Downloading geographiclib-2.0-py3-none-any.whl.metadata (1.4 kB)
# Downloading geopy-2.4.1-py3-none-any.whl (125 kB)
# Downloading geographiclib-2.0-py3-none-any.whl (40 kB)
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-2.0 geopy-2.4.1

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="myapplication")
geolocator.geocode("Canada")
# Out:
# Location(Canada, (61.0666922, -107.991707, 0.0))

# %%
# get the cordinates of the countries from its name
import geopy
from geopy.geocoders import Nominatim
data_2019 = data_2019.iloc[:10]
geolocator = Nominatim(user_agent='myapplication')
data_2019['coordinates'] = data_2019['Country'].apply(geolocator.geocode).apply(lambda x: (x.latitude, x.longitude))
data_2019.head()
# Out:
#                 Country  Infant Mortality Rate  Gender    Year  \
# 0           Afghanistan              43.050731  Female  2019.0
# 1                Angola              44.851045  Female  2019.0
# 2               Albania               7.659442  Female  2019.0
# 3               Andorra               2.555451  Female  2019.0
# 4  United Arab Emirates               5.716825  Female  2019.0
#
#                  coordinates
# 0   (33.7680065, 66.2385139)
# 1  (-11.8775768, 17.5691241)
# 2   (5.7587654, -73.9151617)
# 3    (42.5407167, 1.5732033)
# 4   (24.0002488, 53.9994829)

# %%
import json

# formulate the json file for choropleth map
locations = ", ".join(data_2019['coordinates'].apply(lambda x: str(x).replace('(',"[").replace(')',"]")).tolist())
locations

json_content = f'''
{{
  "type": "FeatureCollection",
  "features": [{{
      "type": "Feature",
      "properties": {{
        "name": "Afghanistan"
      }},
      "geometry": {{
        "type": "Polygon",
        "coordinates": [
            [
                {locations}
            ]
        ]
      }}
  }}]
    
}}
'''
json.loads(json_content)
# with open('data\\countries.json', 'w') as f:
    # f.write(json_content)
# Out:
#   Cell In[41], line 29
#     f.write(json_content)
#     ^
# IndentationError: unexpected indent

# %%
# create a choropleth map
map = folium.Map(zoom_start=2)
world_geo = 'data\\countries.json'

# Ensure the column names match the data
data_2019 = data_2019.rename(columns={'Country': 'Country', 'Infant Mortality Rate': 'Infant Mortality Rate'})

folium.Choropleth(
    geo_data=world_geo,
    data=data_2019,
    columns=['Country', 'Infant Mortality Rate'],
    key_on='feature.properties.name',
    fill_color='YlGnBu',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Infant Mortality Rate'
).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3141d5a74ab4f16cef558d0149fa265e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3141d5a74ab4f16cef558d0149fa265e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3141d5a74ab4f16cef558d0149fa265e = L.map(
#                 &quot;map_3141d5a74ab4f16cef558d0149fa265e&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_814c9e1c6e741db4184aa2143c8d0b26 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_814c9e1c6e741db4184aa2143c8d0b26.addTo(map_3141d5a74ab4f16cef558d0149fa265e);
#
#
#             var choropleth_a6e4e06552cdfec4bd0099c7fa530d1f = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_656b0c3071859cb63c967af21ebd9694_styler(feature) {
#             switch(feature.properties.name) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#253494&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_656b0c3071859cb63c967af21ebd9694_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_656b0c3071859cb63c967af21ebd9694 = L.geoJson(null, {
#                 onEachFeature: geo_json_656b0c3071859cb63c967af21ebd9694_onEachFeature,
#
#                 style: geo_json_656b0c3071859cb63c967af21ebd9694_styler,
#             ...{
# }
#         });
#
#         function geo_json_656b0c3071859cb63c967af21ebd9694_add (data) {
#             geo_json_656b0c3071859cb63c967af21ebd9694
#                 .addData(data);
#         }
#             geo_json_656b0c3071859cb63c967af21ebd9694_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[33.7680065, 66.2385139], [-11.8775768, 17.5691241], [5.7587654, -73.9151617], [42.5407167, 1.5732033], [24.0002488, 53.9994829], [-34.9964963, -64.9672817], [4.536307, -75.6723751], [17.2234721, -61.9554608], [-24.7761086, 134.755], [47.59397, 14.12456]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;Afghanistan&quot;}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_656b0c3071859cb63c967af21ebd9694.addTo(choropleth_a6e4e06552cdfec4bd0099c7fa530d1f);
#
#
#     var color_map_6391a38268e2ee200fb75d36e3558ea5 = {};
#
#
#     color_map_6391a38268e2ee200fb75d36e3558ea5.color = d3.scale.threshold()
#               .domain([2.55545069782505, 2.640211408796547, 2.7249721197680445, 2.8097328307395415, 2.8944935417110385, 2.9792542526825354, 3.064014963654033, 3.1487756746255298, 3.233536385597027, 3.318297096568524, 3.403057807540021, 3.487818518511518, 3.5725792294830154, 3.6573399404545124, 3.74210065142601, 3.8268613623975067, 3.9116220733690037, 3.9963827843405006, 4.081143495311998, 4.165904206283495, 4.250664917254992, 4.335425628226489, 4.420186339197986, 4.504947050169483, 4.58970776114098, 4.674468472112478, 4.759229183083974, 4.843989894055472, 4.928750605026969, 5.013511315998466, 5.098272026969963, 5.18303273794146, 5.267793448912958, 5.352554159884455, 5.4373148708559516, 5.5220755818274485, 5.6068362927989455, 5.691597003770443, 5.776357714741939, 5.861118425713437, 5.945879136684933, 6.030639847656431, 6.115400558627928, 6.200161269599425, 6.284921980570923, 6.369682691542419, 6.454443402513917, 6.539204113485414, 6.623964824456911, 6.7087255354284085, 6.793486246399905, 6.8782469573714025, 6.9630076683428985, 7.047768379314396, 7.132529090285892, 7.21728980125739, 7.302050512228888, 7.386811223200384, 7.471571934171882, 7.556332645143378, 7.641093356114876, 7.725854067086374, 7.81061477805787, 7.895375489029368, 7.980136200000864, 8.064896910972362, 8.14965762194386, 8.234418332915356, 8.319179043886853, 8.40393975485835, 8.488700465829847, 8.573461176801345, 8.658221887772841, 8.742982598744339, 8.827743309715835, 8.912504020687333, 8.997264731658829, 9.082025442630327, 9.166786153601823, 9.25154686457332, 9.336307575544817, 9.421068286516315, 9.505828997487813, 9.590589708459309, 9.675350419430806, 9.760111130402302, 9.8448718413738, 9.929632552345298, 10.014393263316794, 10.099153974288292, 10.183914685259788, 10.268675396231286, 10.353436107202784, 10.43819681817428, 10.522957529145778, 10.607718240117274, 10.692478951088772, 10.777239662060268, 10.862000373031766, 10.946761084003262, 11.03152179497476, 11.116282505946257, 11.201043216917753, 11.285803927889251, 11.370564638860747, 11.455325349832245, 11.540086060803
